# %%
from obligations_parser import Obligations_parser, DataProcessing

from selenium.webdriver.firefox.options import Options
from selenium.webdriver import Firefox, Chrome
from datetime import datetime
import pandas as pd

dataprocessing = DataProcessing()

# %%
url = 'https://www.tinkoff.ru/invest/bonds/?start=0&end=12&country=Russian&orderType=Desc&sortType=ByYieldToClient'

# %% [markdown]
# Если парсим с нуля

# %%
UA = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:124.0) Gecko/20100101 Firefox/124.0'

options = Options()
options.set_preference('general.useragent.override', UA)

# Инициализация драйвера Firefox с установленными опциями
# driver = Firefox(options=options)
driver = Chrome(options=options)

# %%
parser = Obligations_parser(driver, url)

# %% [markdown]
# ---
# Если парсим то, что осталось после вылета

# %%
df = pd.read_csv('Obligations_data_parsed_848_15.01.2024.csv').drop('Unnamed: 0', axis = 1).fillna(0)

# %%
driver.switch_to.window(driver.window_handles[0])
parser_object = Obligations_parser(driver=driver, url=dataprocessing.change_url(url, df['Код'].size, df['Код'].size + 12), existing_df=df)

# %%
df = parser_object.elements_iterator()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df = parser_object.elements_iterator()
#
# NameError: name 'parser_object' is not defined

# %%
df = parser_object.obligations_data

# %%
df
# Out:
#                         Название           Код          Цена  Рейтинг  \
# 0               Ferroni выпуск 1  RU000A103XP8    873.300000   Низкий
# 1               Роснано выпуск 8  RU000A1008V9    863.800000  Средний
# 2       Газпром капитал ЗО24-2-Е  RU000A105GZ7  95773.637065  Высокий
# 3                  Руссойл БО-01  RU000A1074E7    995.000000   Низкий
# 4           Сегежа 002P выпуск 3  RU000A104FG2    992.500000  Средний
# ..                           ...           ...           ...      ...
# 0               ППК РЭО выпуск 1  RU000A105RW1     -1.000000  Средний
# 0               ЕвроХим выпуск 7  RU000A101L96     -1.000000  Средний
# 0               Группа Черкизово  RU000A105M67     -1.000000  Средний
# 0   Бизнес-Недвижимость выпуск 2  RU000A104BY4     -1.000000  Средний
# 0          Автодор БО-5 выпуск 4  RU000A106XM8     -1.000000  Средний
#
#     Срок(месяца)          Дата купона  Величина купона(-13%)  Номинал  \
# 0           20.0           2024-01-16                   9.22   1000.0
# 1           50.0           2024-04-01                  58.20   1000.0
# 2            0.0           2024-01-24                2482.28  96751.7
# 3           33.0                    0                   0.00      0.0
# 4          155.0           2024-01-24                  23.58   1000.0
# ..           ...                  ...                    ...      ...
# 0          107.0  2024-03-29 00:00:00                  38.98   1000.0
# 0           14.0  2024-04-11 00:00:00                  35.76   1000.0
# 0           46.0  2024-03-14 00:00:00                  24.45   1000.0
# 0           35.0  2024-03-22 00:00:00                  23.40   1000.0
# 0           32.0  2024-01-26 00:00:00                  41.93   1000.0
#
#     Выплат в год  Доходность(год)  Доходность(все время)  Доходность(% в год)  \
# 0           12.0           110.64                   9.22                12.67
# 1            2.0           116.40                1455.00                13.48
# 2            1.0          2482.28                   0.00                 2.59
# 3            0.0             0.00                   0.00                 0.00
# 4            4.0            94.32                 896.04                 9.50
# ..           ...              ...                    ...                  ...
# 0            4.0           155.92                1013.48            -15592.00
# 0            2.0            71.52                 250.32             -7152.00
# 0            4.0            97.80                 268.95             -9780.00
# 0            4.0            93.60                 187.20             -9360.00
# 0            4.0           167.72                 335.44            -16772.00
#
#                                                Ссылка     НКД
# 0   https://www.tinkoff.ru/invest/bonds/RU000A103XP8/     0.0
# 1   https://www.tinkoff.ru/invest/bonds/RU000A1008V9/    39.0
# 2   https://www.tinkoff.ru/invest/bonds/RU000A105GZ7/  2790.0
# 3   https://www.tinkoff.ru/invest/bonds/RU000A1074E7/     0.0
# 4   https://www.tinkoff.ru/invest/bonds/RU000A104FG2/    24.0
# ..                                                ...     ...
# 0   https://www.tinkoff.ru/invest/bonds/RU000A105RW1/     8.0
# 0   https://www.tinkoff.ru/invest/bonds/RU000A101L96/    21.0
# 0   https://www.tinkoff.ru/invest/bonds/RU000A105M67/    10.0
# 0   https://www.tinkoff.ru/invest/bonds/RU000A104BY4/     7.0
# 0   https://www.tinkoff.ru/invest/bonds/RU000A106XM8/    44.0
#
# [916 rows x 14 columns]

# %% [markdown]
# ---

# %% [markdown]
# Парсим с нуля

# %%
parser.elements_iterator()
# Out:
# {'Название': ['Роснано выпуск 8'], 'Код': ['RU000A1008V9'], 'Цена': [857.2], 'Рейтинг': ['Средний'], 'Срок(месяца)': [48], 'Дата купона': Timestamp('2024-04-01 00:00:00'), 'НКД': 64.0, 'Величина купона(-13%)': [58.2], 'Номинал': [1000.0], 'Выплат в год': [2], 'Доходность(год)': [116.4], 'Доходность(все время)': [1396.8], 'Доходность(% в год)': [13.58]}
# 1
#
# {'Название': ['Ferroni выпуск 1'], 'Код': ['RU000A103XP8'], 'Цена': [840.5], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [18], 'Дата купона': Timestamp('2024-04-15 00:00:00'), 'НКД': 3.0, 'Величина купона(-13%)': [9.22], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [110.64], 'Доходность(все время)': [9.22], 'Доходность(% в год)': [13.16]}
# 2
#
# {'Название': ['Роснано БО-002P выпуск 4'], 'Код': ['RU000A101KK0'], 'Цена': [993.9], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [0], 'Дата купона': Timestamp('2024-03-26 00:00:00'), 'НКД': 16.0, 'Величина купона(-13%)': [14.79], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [59.16], 'Доходность(все время)': [0.0], 'Доходность(% в год)': [5.95]}
# 3
#
# {'Название': ['МФК Быстроденьги выпуск 2'], 'Код': ['RU000A102ZT7'], 'Цена': [997.4], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [0], 'Дата купона': Timestamp('2024-03-28 00:00:00'), 'НКД': 9.0, 'Величина купона(-13%)': [9.05], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [108.6], 'Доходность(все время)': [0.0], 'Доходность(% в год)': [10.89]}
# 4
#
# Облигация с колл-опционом
# {'Название': ['Alfa Bank'], 'Код': ['RU000A100GW5'], 'Цена': [8500000.0], 'Рейтинг': ['Средний']}
# 5
#
# Облигация с колл-опционом
# {'Название': ['ВТБ СУБ выпуск 5'], 'Код': ['RU000A1034P7'], 'Цена': [6500000.0], 'Рейтинг': ['Средний']}
# 6
#
# Облигация с колл-опционом
# {'Название': ['ВТБ СУБ выпуск 1'], 'Код': ['RU000A102QJ7'], 'Цена': [8335062.0], 'Рейтинг': ['Высокий']}
# 7
#
# {'Название': ['Сегежа Групп 003P-02R'], 'Код': ['RU000A105SP3'], 'Цена': [865.0], 'Рейтинг': ['Средний'], 'Срок(месяца)': [165], 'Дата купона': Timestamp('2024-05-03 00:00:00'), 'НКД': 15.0, 'Величина купона(-13%)': [22.97], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [91.88], 'Доходность(все время)': [941.77], 'Доходность(% в год)': [10.62]}
# 8
#
# {'Название': ['Сегежа 002P выпуск 5'], 'Код': ['RU000A1053P7'], 'Цена': [790.8], 'Рейтинг': ['Средний'], 'Срок(месяца)': [160], 'Дата купона': Timestamp('2024-08-15 00:00:00'), 'НКД': 11.0, 'Величина купона(-13%)': [46.11], 'Номинал': [1000.0], 'Выплат в год': [2], 'Доходность(год)': [92.22], 'Доходность(все время)': [3688.8], 'Доходность(% в год)': [11.66]}
# 9
#
# Облигация с колл-опционом
# {'Название': ['ВТБ СУБ выпуск 12'], 'Код': ['RU000A103SC6'], 'Цена': [8450000.0], 'Рейтинг': ['Средний']}
# 10
#
# Облигация с колл-опционом
# {'Название': ['ЕнисейАгроСоюз 001Р-01'], 'Код': ['RU000A107R29'], 'Цена': [997.0], 'Рейтинг': ['Средний'], 'Срок(месяца)': [58]}
# 11
#
# {'Название': ['Пионер-Лизинг'], 'Код': ['RU000A104V00'], 'Цена': [1000.1], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [96], 'Дата купона': Timestamp('2024-03-28 00:00:00'), 'НКД': 15.0, 'Величина купона(-13%)': [14.79], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [177.48], 'Доходность(все время)': [118.32], 'Доходность(% в год)': [17.75]}
# 12
#
# {'Название': ['Сегежа 002P выпуск 1'], 'Код': ['RU000A1041B2'], 'Цена': [926.4], 'Рейтинг': ['Средний'], 'Срок(месяца)': [151], 'Дата купона': Timestamp('2024-05-15 00:00:00'), 'НКД': 35.0, 'Величина купона(-13%)': [42.72], 'Номинал': [1000.0], 'Выплат в год': [2], 'Доходность(год)': [85.44], 'Доходность(все время)': [3204.0], 'Доходность(% в год)': [9.22]}
# 13
#
# {'Название': ['ХК Финанс выпуск 8'], 'Код': ['RU000A104XU6'], 'Цена': [997.3], 'Рейтинг': ['Средний'], 'Срок(месяца)': [15], 'Дата купона': Timestamp('2024-04-05 00:00:00'), 'НКД': 28.0, 'Величина купона(-13%)': [28.19], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [112.76], 'Доходность(все время)': [84.57], 'Доходность(% в год)': [11.31]}
# 14
#
# {'Название': ['Славянск ЭКО выпуск 1'], 'Код': ['RU000A103WB0'], 'Цена': [945.0], 'Рейтинг': ['Средний'], 'Срок(месяца)': [30], 'Дата купона': Timestamp('2024-04-16 00:00:00'), 'НКД': 20.0, 'Величина купона(-13%)': [23.84], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [95.36], 'Доходность(все время)': [166.88], 'Доходность(% в год)': [10.09]}
# 15
#
# {'Название': ['АПРИ Флай Плэнинг БО-П5'], 'Код': ['RU000A103N19'], 'Цена': [921.4], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [17], 'Дата купона': Timestamp('2024-06-04 00:00:00'), 'НКД': 7.0, 'Величина купона(-13%)': [28.19], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [112.76], 'Доходность(все время)': [112.76], 'Доходность(% в год)': [12.24]}
# 16
#
# {'Название': ['МигКредит БО-03'], 'Код': ['RU000A106UK8'], 'Цена': [979.4], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [28], 'Дата купона': Timestamp('2024-04-04 00:00:00'), 'НКД': 9.0, 'Величина купона(-13%)': [11.92], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [143.04], 'Доходность(все время)': [23.84], 'Доходность(% в год)': [14.6]}
# 17
#
# {'Название': ['М.Видео выпуск 4'], 'Код': ['RU000A106540'], 'Цена': [922.7], 'Рейтинг': ['Средний'], 'Срок(месяца)': [24], 'Дата купона': Timestamp('2024-04-19 00:00:00'), 'НКД': 23.0, 'Величина купона(-13%)': [28.27], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [113.08], 'Доходность(все время)': [169.62], 'Доходность(% в год)': [12.26]}
# 18
#
# {'Название': ['Онлайн Микрофинанс выпуск 1'], 'Код': ['RU000A103406'], 'Цена': [991.0], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [1], 'Дата купона': Timestamp('2024-04-04 00:00:00'), 'НКД': 6.0, 'Величина купона(-13%)': [8.87], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [106.44], 'Доходность(все время)': [0.0], 'Доходность(% в год)': [10.74]}
# 19
#
# {'Название': ['МФК Эйрлоанс выпуск 1'], 'Код': ['RU000A1043L7'], 'Цена': [948.0], 'Рейтинг': ['Средний'], 'Срок(месяца)': [13], 'Дата купона': Timestamp('2024-04-11 00:00:00'), 'НКД': 4.0, 'Величина купона(-13%)': [9.4], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [112.8], 'Доходность(все время)': [9.4], 'Доходность(% в год)': [11.9]}
# 20
#
# {'Название': ['Солид-Лизинг БО-02'], 'Код': ['RU000A107W71'], 'Цена': [1000.0], 'Рейтинг': ['Высокий'], 'Срок(месяца)': [41], 'Дата купона': Timestamp('2024-05-31 00:00:00'), 'НКД': 13.0, 'Величина купона(-13%)': [45.5], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [182.0], 'Доходность(все время)': [455.0], 'Доходность(% в год)': [18.2]}
# 21
#
# {'Название': ['Эфферон выпуск 1'], 'Код': ['RU000A105H98'], 'Цена': [900.0], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [43], 'Дата купона': Timestamp('2024-05-23 00:00:00'), 'НКД': 11.0, 'Величина купона(-13%)': [29.23], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [116.92], 'Доходность(все время)': [292.3], 'Доходность(% в год)': [12.99]}
# 22
#
# {'Название': ['МФК Быстроденьги 002P-04'], 'Код': ['RU000A107GU4'], 'Цена': [1011.3], 'Рейтинг': ['Средний'], 'Срок(месяца)': [38], 'Дата купона': Timestamp('2024-03-25 00:00:00'), 'НКД': 16.0, 'Величина купона(-13%)': [15.66], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [187.92], 'Доходность(все время)': [46.98], 'Доходность(% в год)': [18.58]}
# 23
#
# {'Название': ['АПРИ Флай Плэнинг БО-2Р-02'], 'Код': ['RU000A106631'], 'Цена': [975.2], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [36], 'Дата купона': Timestamp('2024-04-25 00:00:00'), 'НКД': 29.0, 'Величина купона(-13%)': [38.98], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [155.92], 'Доходность(все время)': [350.82], 'Доходность(% в год)': [15.99]}
# 24
#
# {'Название': ['М.Видео выпуск 1'], 'Код': ['RU000A103117'], 'Цена': [993.4], 'Рейтинг': ['Средний'], 'Срок(месяца)': [0], 'Дата купона': Timestamp('2024-04-18 00:00:00'), 'НКД': 47.0, 'Величина купона(-13%)': [47.68], 'Номинал': [1000.0], 'Выплат в год': [2], 'Доходность(год)': [95.36], 'Доходность(все время)': [0.0], 'Доходность(% в год)': [9.6]}
# 25
#
# {'Название': ['Племзавод Пушкинское 001P-03'], 'Код': ['RU000A1080Y2'], 'Цена': [994.5], 'Рейтинг': ['Средний'], 'Срок(месяца)': [59], 'Дата купона': Timestamp('2024-06-13 00:00:00'), 'НКД': 5.0, 'Величина купона(-13%)': [38.98], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [155.92], 'Доходность(все время)': [545.72], 'Доходность(% в год)': [15.68]}
# 26
#
# {'Название': ['Литана выпуск 1'], 'Код': ['RU000A1032S5'], 'Цена': [992.4], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [1], 'Дата купона': Timestamp('2024-05-01 00:00:00'), 'НКД': 19.0, 'Величина купона(-13%)': [28.19], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [112.76], 'Доходность(все время)': [0.0], 'Доходность(% в год)': [11.36]}
# 27
#
# {'Название': ['АПРИ Флай Плэнинг БО-П05'], 'Код': ['RU000A104WA0'], 'Цена': [994.2], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [14], 'Дата купона': Timestamp('2024-06-20 00:00:00'), 'НКД': 2.0, 'Величина купона(-13%)': [38.98], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [155.92], 'Доходность(все время)': [116.94], 'Доходность(% в год)': [15.68]}
# 28
#
# {'Название': ['МФК Мани Мен выпуск 3'], 'Код': ['RU000A103PS8'], 'Цена': [964.5], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [5], 'Дата купона': Timestamp('2024-04-03 00:00:00'), 'НКД': 7.0, 'Величина купона(-13%)': [8.7], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [104.4], 'Доходность(все время)': [0.0], 'Доходность(% в год)': [10.82]}
# 29
#
# {'Название': ['МаксимаТелеком выпуск 2'], 'Код': ['RU000A102DK3'], 'Цена': [983.4], 'Рейтинг': ['Средний'], 'Срок(месяца)': [1], 'Дата купона': Timestamp('2024-05-21 00:00:00'), 'НКД': 33.0, 'Величина купона(-13%)': [42.28], 'Номинал': [1000.0], 'Выплат в год': [2], 'Доходность(год)': [84.56], 'Доходность(все время)': [0.0], 'Доходность(% в год)': [8.6]}
# 30
#
# {'Название': ['МФК ЦФП выпуск 2'], 'Код': ['RU000A103GL2'], 'Цена': [978.9], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [3], 'Дата купона': Timestamp('2024-04-19 00:00:00'), 'НКД': 1.0, 'Величина купона(-13%)': [9.22], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [110.64], 'Доходность(все время)': [0.0], 'Доходность(% в год)': [11.3]}
# 31
#
# {'Название': ['НИКА обб01'], 'Код': ['RU000A1050X7'], 'Цена': [827.922], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [16], 'Дата купона': Timestamp('2024-04-30 00:00:00'), 'НКД': 19.0, 'Величина купона(-13%)': [27.93], 'Номинал': [860.0], 'Выплат в год': [4], 'Доходность(год)': [111.72], 'Доходность(все время)': [111.72], 'Доходность(% в год)': [13.49]}
# 32
#
# {'Название': ['Вита Лайн 001Р выпуск 3'], 'Код': ['RU000A1036X6'], 'Цена': [982.2], 'Рейтинг': ['Средний'], 'Срок(месяца)': [14], 'Дата купона': Timestamp('2024-05-30 00:00:00'), 'НКД': 6.0, 'Величина купона(-13%)': [21.66], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [86.64], 'Доходность(все время)': [64.98], 'Доходность(% в год)': [8.82]}
# 33
#
# Облигация с колл-опционом
# {'Название': ['Газпром Капитал БЗО26-1-Е'], 'Код': ['RU000A105QX1'], 'Цена': [75063.134302], 'Рейтинг': ['Высокий']}
# 34
#
# {'Название': ['МФК Быстроденьги 002P-05'], 'Код': ['RU000A107PW1'], 'Цена': [1009.1], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [39], 'Дата купона': Timestamp('2024-03-31 00:00:00'), 'НКД': 13.0, 'Величина купона(-13%)': [14.96], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [179.52], 'Доходность(все время)': [44.88], 'Доходность(% в год)': [17.79]}
# 35
#
# {'Название': ['Пионер-Лизинг-БО-П03'], 'Код': ['RU000A1013N6'], 'Цена': [1073.8], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [66], 'Дата купона': Timestamp('2024-04-03 00:00:00'), 'НКД': 12.0, 'Величина купона(-13%)': [15.66], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [187.92], 'Доходность(все время)': [78.3], 'Доходность(% в год)': [17.5]}
# 36
#
# {'Название': ['МФК ВЭББАНКИР выпуск 1'], 'Код': ['RU000A103F43'], 'Цена': [811.06488], 'Рейтинг': ['Средний'], 'Срок(месяца)': [9], 'Дата купона': Timestamp('2024-04-07 00:00:00'), 'НКД': 4.0, 'Величина купона(-13%)': [7.57], 'Номинал': [833.4], 'Выплат в год': [12], 'Доходность(год)': [90.84], 'Доходность(все время)': [0.0], 'Доходность(% в год)': [11.2]}
# 37
#
# {'Название': ['М.Видео выпуск 3'], 'Код': ['RU000A104ZK2'], 'Цена': [911.9], 'Рейтинг': ['Средний'], 'Срок(месяца)': [15], 'Дата купона': Timestamp('2024-04-23 00:00:00'), 'НКД': 21.0, 'Величина купона(-13%)': [26.71], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [106.84], 'Доходность(все время)': [80.13], 'Доходность(% в год)': [11.72]}
# 38
#
# {'Название': ['МФК ВЭББАНКИР выпуск 4'], 'Код': ['RU000A106Y88'], 'Цена': [929.6], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [35], 'Дата купона': Timestamp('2024-03-24 00:00:00'), 'НКД': 0.0, 'Величина купона(-13%)': [14.27], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [171.24], 'Доходность(все время)': [28.54], 'Доходность(% в год)': [18.42]}
# 39
#
# Облигация с колл-опционом
# {'Название': ['РКК выпуск 3'], 'Код': ['RU000A106GZ5'], 'Цена': [938.0], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [51]}
# 40
#
# {'Название': ['AzurDrive выпуск 1'], 'Код': ['RU000A106TJ2'], 'Цена': [932.5], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [40], 'Дата купона': Timestamp('2024-03-28 00:00:00'), 'НКД': 11.0, 'Величина купона(-13%)': [11.4], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [136.8], 'Доходность(все время)': [34.2], 'Доходность(% в год)': [14.67]}
# 41
#
# Облигация с колл-опционом
# {'Название': ['Пионер-Лизинг-БО-П04'], 'Код': ['RU000A102LF6'], 'Цена': [1004.7], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [80]}
# 42
#
# Облигация с колл-опционом
# {'Название': ['Электроаппарат БО-01'], 'Код': ['RU000A104WZ7'], 'Цена': [990.5], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [27]}
# 43
#
# {'Название': ['МигКредит 002MC-03'], 'Код': ['RU000A107KR2'], 'Цена': [1010.7], 'Рейтинг': ['Средний'], 'Срок(месяца)': [33], 'Дата купона': Timestamp('2024-04-15 00:00:00'), 'НКД': 5.0, 'Величина купона(-13%)': [14.96], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [179.52], 'Доходность(все время)': [29.92], 'Доходность(% в год)': [17.76]}
# 44
#
# {'Название': ['ПР-Лизинг выпуск 3'], 'Код': ['RU000A100Q35'], 'Цена': [949.3], 'Рейтинг': ['Средний'], 'Срок(месяца)': [27], 'Дата купона': Timestamp('2024-04-18 00:00:00'), 'НКД': 1.0, 'Величина купона(-13%)': [7.83], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [93.96], 'Доходность(все время)': [15.66], 'Доходность(% в год)': [9.9]}
# 45
#
# {'Название': ['Фордевинд 03'], 'Код': ['RU000A106Q47'], 'Цена': [930.8], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [33], 'Дата купона': Timestamp('2024-04-06 00:00:00'), 'НКД': 7.0, 'Величина купона(-13%)': [11.4], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [136.8], 'Доходность(все время)': [22.8], 'Доходность(% в год)': [14.7]}
# 46
#
# {'Название': ['Солид-Лизинг выпуск 1'], 'Код': ['RU000A104CF1'], 'Цена': [667.03], 'Рейтинг': ['Средний'], 'Срок(месяца)': [32], 'Дата купона': Timestamp('2024-03-26 00:00:00'), 'НКД': 25.0, 'Величина купона(-13%)': [22.01], 'Номинал': [700.0], 'Выплат в год': [4], 'Доходность(год)': [88.04], 'Доходность(все время)': [176.08], 'Доходность(% в год)': [13.2]}
# 47
#
# {'Название': ['Фордевинд2'], 'Код': ['RU000A106DK4'], 'Цена': [945.4], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [26], 'Дата купона': Timestamp('2024-04-10 00:00:00'), 'НКД': 6.0, 'Величина купона(-13%)': [11.4], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [136.8], 'Доходность(все время)': [22.8], 'Доходность(% в год)': [14.47]}
# 48
#
# {'Название': ['ПЗ Пушкинское 001P-02'], 'Код': ['RU000A107LU4'], 'Цена': [999.3], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [57], 'Дата купона': Timestamp('2024-04-23 00:00:00'), 'НКД': 32.0, 'Величина купона(-13%)': [41.15], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [164.6], 'Доходность(все время)': [576.1], 'Доходность(% в год)': [16.47]}
# 49
#
# {'Название': ['Пионер-Лизинг-БО-П02'], 'Код': ['RU000A1006C3'], 'Цена': [1089.7], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [57], 'Дата купона': Timestamp('2024-04-17 00:00:00'), 'НКД': 4.0, 'Величина купона(-13%)': [15.83], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [189.96], 'Доходность(все время)': [63.32], 'Доходность(% в год)': [17.43]}
# 50
#
# Облигация с колл-опционом
# {'Название': ['Мегатакт-НН БО-01'], 'Код': ['RU000A107PM2'], 'Цена': [1012.0], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [46]}
# 51
#
# {'Название': ['МФК Лайм-Займ 1Р-02'], 'Код': ['RU000A106CJ8'], 'Цена': [869.76], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [25], 'Дата купона': Timestamp('2024-04-03 00:00:00'), 'НКД': 8.0, 'Величина купона(-13%)': [10.61], 'Номинал': [900.0], 'Выплат в год': [12], 'Доходность(год)': [127.32], 'Доходность(все время)': [21.22], 'Доходность(% в год)': [14.64]}
# 52
#
# {'Название': ['АПРИ Флай Плэнинг выпуск 3'], 'Код': ['RU000A106WZ2'], 'Цена': [1007.6], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [41], 'Дата купона': Timestamp('2024-06-18 00:00:00'), 'НКД': 3.0, 'Величина купона(-13%)': [45.5], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [182.0], 'Доходность(все время)': [455.0], 'Доходность(% в год)': [18.06]}
# 53
#
# {'Название': ['МигКредит БО-02'], 'Код': ['RU000A106KT0'], 'Цена': [954.8], 'Рейтинг': ['Средний'], 'Срок(месяца)': [27], 'Дата купона': Timestamp('2024-04-14 00:00:00'), 'НКД': 4.0, 'Величина купона(-13%)': [10.53], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [126.36], 'Доходность(все время)': [21.06], 'Доходность(% в год)': [13.23]}
# 54
#
# {'Название': ['М.Видео выпуск 2'], 'Код': ['RU000A103HT3'], 'Цена': [961.3], 'Рейтинг': ['Средний'], 'Срок(месяца)': [4], 'Дата купона': Timestamp('2024-05-08 00:00:00'), 'НКД': 10.0, 'Величина купона(-13%)': [17.49], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [69.96], 'Доходность(все время)': [17.49], 'Доходность(% в год)': [7.28]}
# 55
#
# Облигация с колл-опционом
# {'Название': ['Феррони БО-02'], 'Код': ['RU000A105P64'], 'Цена': [881.28], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [20]}
# 56
#
# {'Название': ['Маныч-Агро выпуск 1'], 'Код': ['RU000A1032D7'], 'Цена': [952.0], 'Рейтинг': ['Средний'], 'Срок(месяца)': [13], 'Дата купона': Timestamp('2024-04-26 00:00:00'), 'НКД': 19.0, 'Величина купона(-13%)': [26.01], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [104.04], 'Доходность(все время)': [78.03], 'Доходность(% в год)': [10.93]}
# 57
#
# {'Название': ['МФК ВЭББАНКИР 1P-02'], 'Код': ['RU000A105575'], 'Цена': [901.2], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [22], 'Дата купона': Timestamp('2024-03-23 00:00:00'), 'НКД': 0.0, 'Величина купона(-13%)': [10.0], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [120.0], 'Доходность(все время)': [10.0], 'Доходность(% в год)': [13.32]}
# 58
#
# {'Название': ['Фордевинд 04'], 'Код': ['RU000A106SE5'], 'Цена': [963.6], 'Рейтинг': ['Средний'], 'Срок(месяца)': [34], 'Дата купона': Timestamp('2024-03-25 00:00:00'), 'НКД': 12.0, 'Величина купона(-13%)': [12.09], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [145.08], 'Доходность(все время)': [24.18], 'Доходность(% в год)': [15.06]}
# 59
#
# {'Название': ['МФК Лайм-Займ выпуск 2'], 'Код': ['RU000A105AJ4'], 'Цена': [810.0], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [18], 'Дата купона': Timestamp('2024-04-05 00:00:00'), 'НКД': 8.0, 'Величина купона(-13%)': [11.4], 'Номинал': [800.0], 'Выплат в год': [12], 'Доходность(год)': [136.8], 'Доходность(все время)': [11.4], 'Доходность(% в год)': [16.89]}
# 60
#
# {'Название': ['АйДи Коллект выпуск 1'], 'Код': ['RU000A103HG0'], 'Цена': [978.1], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [4], 'Дата купона': Timestamp('2024-03-27 00:00:00'), 'НКД': 9.0, 'Величина купона(-13%)': [8.53], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [102.36], 'Доходность(все время)': [0.0], 'Доходность(% в год)': [10.47]}
# 61
#
# {'Название': ['Селлер выпуск 1'], 'Код': ['RU000A106KY0'], 'Цена': [992.3], 'Рейтинг': ['Средний'], 'Срок(месяца)': [15], 'Дата купона': Timestamp('2024-04-14 00:00:00'), 'НКД': 4.0, 'Величина купона(-13%)': [12.79], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [153.48], 'Доходность(все время)': [12.79], 'Доходность(% в год)': [15.47]}
# 62
#
# {'Название': ['БЭЛТИ-ГРАНД выпуск 4'], 'Код': ['RU000A103DY2'], 'Цена': [773.5], 'Рейтинг': ['Средний'], 'Срок(месяца)': [34], 'Дата купона': Timestamp('2024-03-30 00:00:00'), 'НКД': 7.0, 'Величина купона(-13%)': [7.39], 'Номинал': [850.0], 'Выплат в год': [12], 'Доходность(год)': [88.68], 'Доходность(все время)': [14.78], 'Доходность(% в год)': [11.46]}
# 63
#
# {'Название': ['Мани Капитал 001P-01'], 'Код': ['RU000A1074F4'], 'Цена': [948.0], 'Рейтинг': ['Средний'], 'Срок(месяца)': [30], 'Дата купона': Timestamp('2024-04-21 00:00:00'), 'НКД': 1.0, 'Величина купона(-13%)': [14.96], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [179.52], 'Доходность(все время)': [29.92], 'Доходность(% в год)': [18.94]}
# 64
#
# Облигация с колл-опционом
# {'Название': ['Ника (ООО) 001P-03'], 'Код': ['RU000A107SH6'], 'Цена': [1000.0], 'Рейтинг': ['Средний'], 'Срок(месяца)': [58]}
# 65
#
# Облигация с колл-опционом
# {'Название': ['ПР-Лизинг 002P-01'], 'Код': ['RU000A1022E6'], 'Цена': [947.7], 'Рейтинг': ['Средний'], 'Срок(месяца)': [64]}
# 66
#
# {'Название': ['МФК Лайм-Займ 001Р-03'], 'Код': ['RU000A107795'], 'Цена': [994.5], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [31], 'Дата купона': Timestamp('2024-04-13 00:00:00'), 'НКД': 6.0, 'Величина купона(-13%)': [14.27], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [171.24], 'Доходность(все время)': [28.54], 'Доходность(% в год)': [17.22]}
# 67
#
# {'Название': ['МФК ВЭББАНКИР 001Р-04'], 'Код': ['RU000A107U65'], 'Цена': [994.0], 'Рейтинг': ['Средний'], 'Срок(месяца)': [40], 'Дата купона': Timestamp('2024-03-23 00:00:00'), 'НКД': 1.0, 'Величина купона(-13%)': [14.96], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [179.52], 'Доходность(все время)': [44.88], 'Доходность(% в год)': [18.06]}
# 68
#
# {'Название': ['ФЭС-Агро выпуск 2'], 'Код': ['RU000A1030N0'], 'Цена': [497.55], 'Рейтинг': ['Средний'], 'Срок(месяца)': [0], 'Дата купона': Timestamp('2024-04-17 00:00:00'), 'НКД': 10.0, 'Величина купона(-13%)': [11.92], 'Номинал': [500.0], 'Выплат в год': [4], 'Доходность(год)': [47.68], 'Доходность(все время)': [0.0], 'Доходность(% в год)': [9.58]}
# 69
#
# {'Название': ['МигКредит об01'], 'Код': ['RU000A103DA2'], 'Цена': [158.72], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [3], 'Дата купона': Timestamp('2024-03-28 00:00:00'), 'НКД': 1.0, 'Величина купона(-13%)': [1.39], 'Номинал': [160.0], 'Выплат в год': [12], 'Доходность(год)': [16.68], 'Доходность(все время)': [0.0], 'Доходность(% в год)': [10.51]}
# 70
#
# {'Название': ['Завод КЭС 001P-05'], 'Код': ['RU000A107U40'], 'Цена': [1005.5], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [58], 'Дата купона': Timestamp('2024-05-23 00:00:00'), 'НКД': 16.0, 'Величина купона(-13%)': [41.15], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [164.6], 'Доходность(все время)': [576.1], 'Доходность(% в год)': [16.37]}
# 71
#
# {'Название': ['Легенда выпуск 4'], 'Код': ['RU000A102Y66'], 'Цена': [957.2], 'Рейтинг': ['Средний'], 'Срок(месяца)': [12], 'Дата купона': Timestamp('2024-04-09 00:00:00'), 'НКД': 20.0, 'Величина купона(-13%)': [21.58], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [86.32], 'Доходность(все время)': [64.74], 'Доходность(% в год)': [9.02]}
# 72
#
# {'Название': ['БЭЛТИ-ГРАНД БО-П05'], 'Код': ['RU000A105427'], 'Цена': [763.68], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [24], 'Дата купона': Timestamp('2024-04-13 00:00:00'), 'НКД': 3.0, 'Величина купона(-13%)': [8.0], 'Номинал': [800.0], 'Выплат в год': [12], 'Доходность(год)': [96.0], 'Доходность(все время)': [16.0], 'Доходность(% в год)': [12.57]}
# 73
#
# {'Название': ['МФК Саммит 1P-01'], 'Код': ['RU000A105UZ8'], 'Цена': [966.92976], 'Рейтинг': ['Средний'], 'Срок(месяца)': [22], 'Дата купона': Timestamp('2024-04-11 00:00:00'), 'НКД': 6.0, 'Величина купона(-13%)': [13.31], 'Номинал': [958.4], 'Выплат в год': [12], 'Доходность(год)': [159.72], 'Доходность(все время)': [13.31], 'Доходность(% в год)': [16.52]}
# 74
#
# {'Название': ['Мосгорломбард 001Р-05'], 'Код': ['RU000A107UB5'], 'Цена': [1040.0], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [58], 'Дата купона': Timestamp('2024-05-28 00:00:00'), 'НКД': 14.0, 'Величина купона(-13%)': [43.33], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [173.32], 'Доходность(все время)': [606.62], 'Доходность(% в год)': [16.67]}
# 75
#
# {'Название': ['ТЕХНО Лизинг выпуск 4'], 'Код': ['RU000A1032X5'], 'Цена': [878.7], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [24], 'Дата купона': Timestamp('2024-03-27 00:00:00'), 'НКД': 8.0, 'Величина купона(-13%)': [7.66], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [91.92], 'Доходность(все время)': [15.32], 'Доходность(% в год)': [10.46]}
# 76
#
# Облигация с колл-опционом
# {'Название': ['Ника 001P-02'], 'Код': ['RU000A106U74'], 'Цена': [959.7], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [53]}
# 77
#
# {'Название': ['МФК Быстроденьги 2P-02'], 'Код': ['RU000A106B51'], 'Цена': [953.0], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [31], 'Дата купона': Timestamp('2024-03-26 00:00:00'), 'НКД': 12.0, 'Величина купона(-13%)': [11.4], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [136.8], 'Доходность(все время)': [22.8], 'Доходность(% в год)': [14.35]}
# 78
#
# Облигация с колл-опционом
# {'Название': ['Плаза-Телеком БО-01'], 'Код': ['RU000A106YD5'], 'Цена': [992.8], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [29]}
# 79
#
# {'Название': ['ПИМ выпуск 2'], 'Код': ['RU000A106NT4'], 'Цена': [932.8], 'Рейтинг': ['Средний'], 'Срок(месяца)': [28], 'Дата купона': Timestamp('2024-05-02 00:00:00'), 'НКД': 21.0, 'Величина купона(-13%)': [31.41], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [125.64], 'Доходность(все время)': [219.87], 'Доходность(% в год)': [13.47]}
# 80
#
# {'Название': ['А Девелопмент'], 'Код': ['RU000A104FX7'], 'Цена': [961.1], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [9], 'Дата купона': Timestamp('2024-04-25 00:00:00'), 'НКД': 22.0, 'Величина купона(-13%)': [30.02], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [120.08], 'Доходность(все время)': [60.04], 'Доходность(% в год)': [12.49]}
# 81
#
# {'Название': ['МФК Быстроденьги 2P-03'], 'Код': ['RU000A1070G0'], 'Цена': [947.4], 'Рейтинг': ['Средний'], 'Срок(месяца)': [35], 'Дата купона': Timestamp('2024-04-08 00:00:00'), 'НКД': 9.0, 'Величина купона(-13%)': [14.96], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [179.52], 'Доходность(все время)': [29.92], 'Доходность(% в год)': [18.95]}
# 82
#
# {'Название': ['ТрансФин-М 001Р-07'], 'Код': ['RU000A103M36'], 'Цена': [963.8], 'Рейтинг': ['Средний'], 'Срок(месяца)': [88], 'Дата купона': Timestamp('2024-05-27 00:00:00'), 'НКД': 7.0, 'Величина купона(-13%)': [21.23], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [84.92], 'Доходность(все время)': [467.06], 'Доходность(% в год)': [8.81]}
# 83
#
# {'Название': ['Соби-Лизинг 001Р-04'], 'Код': ['RU000A107EE3'], 'Цена': [1008.0], 'Рейтинг': ['Средний'], 'Срок(месяца)': [32], 'Дата купона': Timestamp('2024-04-17 00:00:00'), 'НКД': 3.0, 'Величина купона(-13%)': [13.57], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [162.84], 'Доходность(все время)': [27.14], 'Доходность(% в год)': [16.15]}
# 84
#
# {'Название': ['РКК выпуск 1'], 'Код': ['RU000A105VP7'], 'Цена': [1005.0], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [22], 'Дата купона': Timestamp('2024-05-21 00:00:00'), 'НКД': 17.0, 'Величина купона(-13%)': [41.15], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [164.6], 'Доходность(все время)': [205.75], 'Доходность(% в год)': [16.38]}
# 85
#
# Облигация с колл-опционом
# {'Название': ['Мосрегионлифт БО-02'], 'Код': ['RU000A106DJ6'], 'Цена': [991.4], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [38]}
# 86
#
# {'Название': ['Глобал Факторинг Нетворк Рус выпуск 3'], 'Код': ['RU000A106LS0'], 'Цена': [934.7], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [39], 'Дата купона': Timestamp('2024-04-21 00:00:00'), 'НКД': 1.0, 'Величина купона(-13%)': [10.53], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [126.36], 'Доходность(все время)': [31.59], 'Доходность(% в год)': [13.52]}
# 87
#
# {'Название': ['Группа Продовольствие 001P-03'], 'Код': ['RU000A106YN4'], 'Цена': [955.0], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [29], 'Дата купона': Timestamp('2024-03-26 00:00:00'), 'НКД': 12.0, 'Величина купона(-13%)': [11.4], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [136.8], 'Доходность(все время)': [22.8], 'Доходность(% в год)': [14.32]}
# 88
#
# {'Название': ['СибАвтоТранс 001Р-03'], 'Код': ['RU000A107KV4'], 'Цена': [1011.6], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [57], 'Дата купона': Timestamp('2024-04-18 00:00:00'), 'НКД': 34.0, 'Величина купона(-13%)': [41.15], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [164.6], 'Доходность(все время)': [576.1], 'Доходность(% в год)': [16.27]}
# 89
#
# {'Название': ['Гарант-Инвест 002P-07'], 'Код': ['RU000A106SK2'], 'Цена': [984.9], 'Рейтинг': ['Средний'], 'Срок(месяца)': [52], 'Дата купона': Timestamp('2024-03-26 00:00:00'), 'НКД': 11.0, 'Величина купона(-13%)': [10.35], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [124.2], 'Доходность(все время)': [41.4], 'Доходность(% в год)': [12.61]}
# 90
#
# Облигация с колл-опционом
# {'Название': ['Нафтатранс Плюс выпуск 3'], 'Код': ['RU000A102V51'], 'Цена': [919.6], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [22]}
# 91
#
# {'Название': ['МФК Лайм-Займ выпуск 1'], 'Код': ['RU000A104AX8'], 'Цена': [593.58], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [8], 'Дата купона': Timestamp('2024-06-19 00:00:00'), 'НКД': 1.0, 'Величина купона(-13%)': [21.75], 'Номинал': [600.0], 'Выплат в год': [4], 'Доходность(год)': [87.0], 'Доходность(все время)': [43.5], 'Доходность(% в год)': [14.66]}
# 92
#
# {'Название': ['Нафтатранс Плюс выпуск 2'], 'Код': ['RU000A100YD8'], 'Цена': [3303.693], 'Рейтинг': ['Средний'], 'Срок(месяца)': [6], 'Дата купона': Timestamp('2024-03-30 00:00:00'), 'НКД': 34.0, 'Величина купона(-13%)': [35.67], 'Номинал': [3330.0], 'Выплат в год': [12], 'Доходность(год)': [428.04], 'Доходность(все время)': [0.0], 'Доходность(% в год)': [12.96]}
# 93
#
# {'Название': ['МаксимаТелеком выпуск 1'], 'Код': ['RU000A101XD8'], 'Цена': [932.0], 'Рейтинг': ['Средний'], 'Срок(месяца)': [27], 'Дата купона': Timestamp('2024-07-16 00:00:00'), 'НКД': 18.0, 'Величина купона(-13%)': [41.15], 'Номинал': [1000.0], 'Выплат в год': [2], 'Доходность(год)': [82.3], 'Доходность(все время)': [534.95], 'Доходность(% в год)': [8.83]}
# 94
#
# {'Название': ['Реаторг 001Р-01'], 'Код': ['RU000A105BP9'], 'Цена': [882.0], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [18], 'Дата купона': Timestamp('2024-04-23 00:00:00'), 'НКД': 24.0, 'Величина купона(-13%)': [30.45], 'Номинал': [900.0], 'Выплат в год': [4], 'Доходность(год)': [121.8], 'Доходность(все время)': [121.8], 'Доходность(% в год)': [13.81]}
# 95
#
# {'Название': ['УК ОРГ выпуск 3'], 'Код': ['RU000A106UB7'], 'Цена': [967.0], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [28], 'Дата купона': Timestamp('2024-04-04 00:00:00'), 'НКД': 9.0, 'Величина купона(-13%)': [11.74], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [140.88], 'Доходность(все время)': [23.48], 'Доходность(% в год)': [14.57]}
# 96
#
# {'Название': ['АСВ выпуск 1'], 'Код': ['RU000A106RB3'], 'Цена': [973.3], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [28], 'Дата купона': Timestamp('2024-05-17 00:00:00'), 'НКД': 17.0, 'Величина купона(-13%)': [36.8], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [147.2], 'Доходность(все время)': [257.6], 'Доходность(% в год)': [15.12]}
# 97
#
# {'Название': ['Роял Капитал выпуск 9'], 'Код': ['RU000A106JC8'], 'Цена': [937.9], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [27], 'Дата купона': Timestamp('2024-04-10 00:00:00'), 'НКД': 30.0, 'Величина купона(-13%)': [32.19], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [128.76], 'Доходность(все время)': [193.14], 'Доходность(% в год)': [13.73]}
# 98
#
# {'Название': ['Лизинг трейд выпуск 3'], 'Код': ['RU000A1034X1'], 'Цена': [900.0], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [25], 'Дата купона': Timestamp('2024-04-10 00:00:00'), 'НКД': 4.0, 'Величина купона(-13%)': [7.83], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [93.96], 'Доходность(все время)': [15.66], 'Доходность(% в год)': [10.44]}
# 99
#
# {'Название': ['Урожай выпуск 2'], 'Код': ['RU000A1037C8'], 'Цена': [987.1], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [2], 'Дата купона': Timestamp('2024-06-04 00:00:00'), 'НКД': 6.0, 'Величина купона(-13%)': [24.88], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [99.52], 'Доходность(все время)': [0.0], 'Доходность(% в год)': [10.08]}
# 100
#
# Облигация с колл-опционом
# {'Название': ['Смартфакт БО-02-001P'], 'Код': ['RU000A107EP9'], 'Цена': [1014.0], 'Рейтинг': ['Средний'], 'Срок(месяца)': [32]}
# 101
#
# {'Название': ['Неолизинг выпуск 1'], 'Код': ['RU000A106PY9'], 'Цена': [983.4], 'Рейтинг': ['Средний'], 'Срок(месяца)': [27], 'Дата купона': Timestamp('2024-04-05 00:00:00'), 'НКД': 8.0, 'Величина купона(-13%)': [12.09], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [145.08], 'Доходность(все время)': [24.18], 'Доходность(% в год)': [14.75]}
# 102
#
# {'Название': ['ТЕХНО Лизинг выпуск 5'], 'Код': ['RU000A103TS0'], 'Цена': [847.1], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [41], 'Дата купона': Timestamp('2024-04-21 00:00:00'), 'НКД': 1.0, 'Величина купона(-13%)': [8.18], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [98.16], 'Доходность(все время)': [24.54], 'Доходность(% в год)': [11.59]}
# 103
#
# {'Название': ['ПР-Лизинг выпуск 2'], 'Код': ['RU000A106EP1'], 'Цена': [893.9], 'Рейтинг': ['Средний'], 'Срок(месяца)': [97], 'Дата купона': Timestamp('2024-04-18 00:00:00'), 'НКД': 2.0, 'Величина купона(-13%)': [8.87], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [106.44], 'Доходность(все время)': [70.96], 'Доходность(% в год)': [11.91]}
# 104
#
# {'Название': ['Талан-Финанс выпуск 3'], 'Код': ['RU000A1043B8'], 'Цена': [967.2], 'Рейтинг': ['Средний'], 'Срок(месяца)': [13], 'Дата купона': Timestamp('2024-05-20 00:00:00'), 'НКД': 12.0, 'Величина купона(-13%)': [28.19], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [112.76], 'Доходность(все время)': [84.57], 'Доходность(% в год)': [11.66]}
# 105
#
# {'Название': ['УК ОРГ выпуск 2'], 'Код': ['RU000A106L67'], 'Цена': [968.6], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [27], 'Дата купона': Timestamp('2024-04-19 00:00:00'), 'НКД': 2.0, 'Величина купона(-13%)': [11.74], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [140.88], 'Доходность(все время)': [23.48], 'Доходность(% в год)': [14.54]}
# 106
#
# {'Название': ['АйДи Коллект выпуск 6'], 'Код': ['RU000A107C34'], 'Цена': [999.8], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [31], 'Дата купона': Timestamp('2024-04-05 00:00:00'), 'НКД': 9.0, 'Величина купона(-13%)': [12.79], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [153.48], 'Доходность(все время)': [25.58], 'Доходность(% в год)': [15.35]}
# 107
#
# {'Название': ['ФПК Гарант-Инвест 002Р-08'], 'Код': ['RU000A107TR3'], 'Цена': [999.9], 'Рейтинг': ['Средний'], 'Срок(месяца)': [22], 'Дата купона': Timestamp('2024-04-21 00:00:00'), 'НКД': 1.0, 'Величина купона(-13%)': [12.79], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [153.48], 'Доходность(все время)': [12.79], 'Доходность(% в год)': [15.35]}
# 108
#
# {'Название': ['Бизнес Альянс 1Р-01'], 'Код': ['RU000A105YQ9'], 'Цена': [945.4], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [23], 'Дата купона': Timestamp('2024-06-13 00:00:00'), 'НКД': 4.0, 'Величина купона(-13%)': [32.19], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [128.76], 'Доходность(все время)': [160.95], 'Доходность(% в год)': [13.62]}
# 109
#
# {'Название': ['Джой Мани 001P-01'], 'Код': ['RU000A107EW5'], 'Цена': [1026.3], 'Рейтинг': ['Средний'], 'Срок(месяца)': [32], 'Дата купона': Timestamp('2024-04-18 00:00:00'), 'НКД': 3.0, 'Величина купона(-13%)': [15.66], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [187.92], 'Доходность(все время)': [31.32], 'Доходность(% в год)': [18.31]}
# 110
#
# {'Название': ['Агрофирма Рубеж 001Р-02'], 'Код': ['RU000A107YT9'], 'Цена': [1009.5], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [59], 'Дата купона': Timestamp('2024-06-11 00:00:00'), 'НКД': 6.0, 'Величина купона(-13%)': [40.11], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [160.44], 'Доходность(все время)': [561.54], 'Доходность(% в год)': [15.89]}
# 111
#
# {'Название': ['АСПЭК-Домстрой выпуск 1'], 'Код': ['RU000A104B53'], 'Цена': [737.4], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [8], 'Дата купона': Timestamp('2024-06-20 00:00:00'), 'НКД': 1.0, 'Величина купона(-13%)': [23.58], 'Номинал': [750.0], 'Выплат в год': [4], 'Доходность(год)': [94.32], 'Доходность(все время)': [47.16], 'Доходность(% в год)': [12.79]}
# 112
#
# {'Название': ['Мани Капитал 001P-02'], 'Код': ['RU000A1079G1'], 'Цена': [986.5], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [31], 'Дата купона': Timestamp('2024-03-27 00:00:00'), 'НКД': 16.0, 'Величина купона(-13%)': [15.66], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [187.92], 'Доходность(все время)': [31.32], 'Доходность(% в год)': [19.05]}
# 113
#
# {'Название': ['ЭкономЛизинг выпуск 3'], 'Код': ['RU000A1030U5'], 'Цена': [995.5], 'Рейтинг': ['Средний'], 'Срок(месяца)': [0], 'Дата купона': Timestamp('2024-04-18 00:00:00'), 'НКД': 21.0, 'Величина купона(-13%)': [24.88], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [99.52], 'Доходность(все время)': [0.0], 'Доходность(% в год)': [10.0]}
# 114
#
# {'Название': ['Маныч-Агро'], 'Код': ['RU000A103K20'], 'Цена': [920.1], 'Рейтинг': ['Средний'], 'Срок(месяца)': [22], 'Дата купона': Timestamp('2024-05-16 00:00:00'), 'НКД': 12.0, 'Величина купона(-13%)': [26.01], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [104.04], 'Доходность(все время)': [130.05], 'Доходность(% в год)': [11.31]}
# 115
#
# {'Название': ['Мани Капитал 001P-03'], 'Код': ['RU000A107WD7'], 'Цена': [1000.8], 'Рейтинг': ['Средний'], 'Срок(месяца)': [34], 'Дата купона': Timestamp('2024-04-04 00:00:00'), 'НКД': 12.0, 'Величина купона(-13%)': [15.66], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [187.92], 'Доходность(все время)': [31.32], 'Доходность(% в год)': [18.78]}
# 116
#
# Облигация с колл-опционом
# {'Название': ['РСХБ выпуск T1'], 'Код': ['RU000A0ZZ4T1'], 'Цена': [735.8], 'Рейтинг': ['Средний']}
# 117
#
# {'Название': ['НК Продкорпорация выпуск 1'], 'Код': ['RU000A102BF7'], 'Цена': [899.0], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [24], 'Дата купона': Timestamp('2024-03-26 00:00:00'), 'НКД': 44.0, 'Величина купона(-13%)': [38.98], 'Номинал': [1000.0], 'Выплат в год': [2], 'Доходность(год)': [77.96], 'Доходность(все время)': [467.76], 'Доходность(% в год)': [8.67]}
# 118
#
# Облигация с колл-опционом
# {'Название': ['РСХБ 09Т1'], 'Код': ['RU000A0ZZ505'], 'Цена': [736.1], 'Рейтинг': ['Средний']}
# 119
#
# {'Название': ['ТЕХНО Лизинг выпуск 3'], 'Код': ['RU000A102234'], 'Цена': [944.4], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [16], 'Дата купона': Timestamp('2024-04-07 00:00:00'), 'НКД': 5.0, 'Величина купона(-13%)': [8.87], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [106.44], 'Доходность(все время)': [8.87], 'Доходность(% в год)': [11.27]}
# 120
#
# Облигация с колл-опционом
# {'Название': ['Руссойл БО-01'], 'Код': ['RU000A1074E7'], 'Цена': [1000.0], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [30]}
# 121
#
# Облигация с колл-опционом
# {'Название': ['ГТЛК 002Р-03'], 'Код': ['RU000A107TT9'], 'Цена': [1000.1], 'Рейтинг': ['Высокий'], 'Срок(месяца)': [178]}
# 122
#
# {'Название': ['СмартФ1Р01'], 'Код': ['RU000A106CM2'], 'Цена': [959.0], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [26], 'Дата купона': Timestamp('2024-06-06 00:00:00'), 'НКД': 7.0, 'Величина купона(-13%)': [34.1], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [136.4], 'Доходность(все время)': [204.6], 'Доходность(% в год)': [14.22]}
# 123
#
# {'Название': ['Хайтэк-Интеграция 1P-01'], 'Код': ['RU000A106151'], 'Цена': [952.5], 'Рейтинг': ['Средний'], 'Срок(месяца)': [24], 'Дата купона': Timestamp('2024-03-28 00:00:00'), 'НКД': 36.0, 'Величина купона(-13%)': [32.19], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [128.76], 'Доходность(все время)': [193.14], 'Доходность(% в год)': [13.52]}
# 124
#
# {'Название': ['АПРИ Флай Плэнинг'], 'Код': ['RU000A105DS9'], 'Цена': [1016.7], 'Рейтинг': ['Средний'], 'Срок(месяца)': [31], 'Дата купона': Timestamp('2024-05-07 00:00:00'), 'НКД': 27.0, 'Величина купона(-13%)': [45.5], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [182.0], 'Доходность(все время)': [318.5], 'Доходность(% в год)': [17.9]}
# 125
#
# Облигация с колл-опционом
# {'Название': ['Симпл Солюшнз Кэпитл 001P-01'], 'Код': ['RU000A107SG8'], 'Цена': [1000.7], 'Рейтинг': ['Средний'], 'Срок(месяца)': [116]}
# 126
#
# {'Название': ['Глоракс 1P-01'], 'Код': ['RU000A105XF4'], 'Цена': [974.0], 'Рейтинг': ['Средний'], 'Срок(месяца)': [11], 'Дата купона': Timestamp('2024-06-11 00:00:00'), 'НКД': 5.0, 'Величина купона(-13%)': [32.19], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [128.76], 'Доходность(все время)': [64.38], 'Доходность(% в год)': [13.22]}
# 127
#
# {'Название': ['Соби-Лизинг 001Р-03'], 'Код': ['RU000A1078H1'], 'Цена': [967.478], 'Рейтинг': ['Средний'], 'Срок(месяца)': [31], 'Дата купона': Timestamp('2024-04-19 00:00:00'), 'НКД': 2.0, 'Величина купона(-13%)': [12.09], 'Номинал': [970.0], 'Выплат в год': [12], 'Доходность(год)': [145.08], 'Доходность(все время)': [24.18], 'Доходность(% в год)': [15.0]}
# 128
#
# {'Название': ['Роял Капитал'], 'Код': ['RU000A104UF3'], 'Цена': [972.8], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [14], 'Дата купона': Timestamp('2024-05-28 00:00:00'), 'НКД': 11.0, 'Величина купона(-13%)': [32.19], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [128.76], 'Доходность(все время)': [96.57], 'Доходность(% в год)': [13.24]}
# 129
#
# Облигация с колл-опционом
# {'Название': ['Трейдберри БО-01'], 'Код': ['RU000A106VN0'], 'Цена': [1003.0], 'Рейтинг': ['Средний'], 'Срок(месяца)': [29]}
# 130
#
# {'Название': ['МФК Фордевинд'], 'Код': ['RU000A105849'], 'Цена': [730.944], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [17], 'Дата купона': Timestamp('2024-04-13 00:00:00'), 'НКД': 4.0, 'Величина купона(-13%)': [10.18], 'Номинал': [720.0], 'Выплат в год': [12], 'Доходность(год)': [122.16], 'Доходность(все время)': [10.18], 'Доходность(% в год)': [16.71]}
# 131
#
# {'Название': ['ПИМ выпуск 1'], 'Код': ['RU000A103WD6'], 'Цена': [737.475], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [6], 'Дата купона': Timestamp('2024-04-17 00:00:00'), 'НКД': 18.0, 'Величина купона(-13%)': [21.14], 'Номинал': [750.0], 'Выплат в год': [4], 'Доходность(год)': [84.56], 'Доходность(все время)': [21.14], 'Доходность(% в год)': [11.47]}
# 132
#
# {'Название': ['Петроинжиниринг выпуск 1'], 'Код': ['RU000A103RL9'], 'Цена': [962.4], 'Рейтинг': ['Средний'], 'Срок(месяца)': [29], 'Дата купона': Timestamp('2024-06-21 00:00:00'), 'НКД': 0.0, 'Величина купона(-13%)': [21.14], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [84.56], 'Доходность(все время)': [147.98], 'Доходность(% в год)': [8.79]}
# 133
#
# {'Название': ['Роял Капитал БО-П10'], 'Код': ['RU000A1079H9'], 'Цена': [1001.0], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [31], 'Дата купона': Timestamp('2024-05-28 00:00:00'), 'НКД': 14.0, 'Величина купона(-13%)': [43.33], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [173.32], 'Доходность(все время)': [303.31], 'Доходность(% в год)': [17.31]}
# 134
#
# {'Название': ['Сегежа'], 'Код': ['RU000A104UA4'], 'Цена': [969.8], 'Рейтинг': ['Средний'], 'Срок(месяца)': [157], 'Дата купона': Timestamp('2024-05-27 00:00:00'), 'НКД': 11.0, 'Величина купона(-13%)': [32.19], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [128.76], 'Доходность(все время)': [1255.41], 'Доходность(% в год)': [13.28]}
# 135
#
# {'Название': ['КЛС-Трейд БО-02'], 'Код': ['RU000A105QL6'], 'Цена': [1000.7], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [9], 'Дата купона': Timestamp('2024-04-09 00:00:00'), 'НКД': 37.0, 'Величина купона(-13%)': [38.98], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [155.92], 'Доходность(все время)': [77.96], 'Доходность(% в год)': [15.58]}
# 136
#
# {'Название': ['СОБИЛИЗ1Р2'], 'Код': ['RU000A106AK0'], 'Цена': [793.432], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [25], 'Дата купона': Timestamp('2024-03-25 00:00:00'), 'НКД': 8.0, 'Величина купона(-13%)': [8.35], 'Номинал': [820.0], 'Выплат в год': [12], 'Доходность(год)': [100.2], 'Доходность(все время)': [16.7], 'Доходность(% в год)': [12.63]}
# 137
#
# Облигация с колл-опционом
# {'Название': ['Электрощит-Стройсистема выпуск 2'], 'Код': ['RU000A101UD4'], 'Цена': [944.0], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [14]}
# 138
#
# {'Название': ['Селлер выпуск 2'], 'Код': ['RU000A106X30'], 'Цена': [994.2], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [29], 'Дата купона': Timestamp('2024-04-16 00:00:00'), 'НКД': 4.0, 'Величина купона(-13%)': [12.79], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [153.48], 'Доходность(все время)': [25.58], 'Доходность(% в год)': [15.44]}
# 139
#
# {'Название': ['Центр-Резерв БО-01'], 'Код': ['RU000A104TG3'], 'Цена': [889.95], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [19], 'Дата купона': Timestamp('2024-04-06 00:00:00'), 'НКД': 9.0, 'Величина купона(-13%)': [13.31], 'Номинал': [850.0], 'Выплат в год': [12], 'Доходность(год)': [159.72], 'Доходность(все время)': [13.31], 'Доходность(% в год)': [17.95]}
# 140
#
# {'Название': ['Мой самокат БО-01'], 'Код': ['RU000A107PE9'], 'Цена': [1033.6], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [21], 'Дата купона': Timestamp('2024-03-29 00:00:00'), 'НКД': 14.0, 'Величина купона(-13%)': [14.27], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [171.24], 'Доходность(все время)': [14.27], 'Доходность(% в год)': [16.57]}
# 141
#
# {'Название': ['Айди Коллект выпуск 3'], 'Код': ['RU000A1065M8'], 'Цена': [955.0], 'Рейтинг': ['Средний'], 'Срок(месяца)': [24], 'Дата купона': Timestamp('2024-04-20 00:00:00'), 'НКД': 1.0, 'Величина купона(-13%)': [10.7], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [128.4], 'Доходность(все время)': [21.4], 'Доходность(% в год)': [13.45]}
# 142
#
# {'Название': ['КИФА выпуск 1'], 'Код': ['RU000A106EV9'], 'Цена': [957.0], 'Рейтинг': ['Средний'], 'Срок(месяца)': [26], 'Дата купона': Timestamp('2024-03-25 00:00:00'), 'НКД': 35.0, 'Величина купона(-13%)': [31.41], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [125.64], 'Доходность(все время)': [188.46], 'Доходность(% в год)': [13.13]}
# 143
#
# Облигация с колл-опционом
# {'Название': ['Моторные технологии 001Р-04'], 'Код': ['RU000A107TD3'], 'Цена': [1005.8], 'Рейтинг': ['Средний'], 'Срок(месяца)': [58]}
# 144
#
# {'Название': ['Завод КЭС выпуск 4'], 'Код': ['RU000A106QS9'], 'Цена': [911.8], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [52], 'Дата купона': Timestamp('2024-06-14 00:00:00'), 'НКД': 4.0, 'Величина купона(-13%)': [31.41], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [125.64], 'Доходность(все время)': [408.33], 'Доходность(% в год)': [13.78]}
# 145
#
# {'Название': ['РКК выпуск 2'], 'Код': ['RU000A105ZW4'], 'Цена': [1004.8], 'Рейтинг': ['Средний'], 'Срок(месяца)': [35], 'Дата купона': Timestamp('2024-06-20 00:00:00'), 'НКД': 2.0, 'Величина купона(-13%)': [38.98], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [155.92], 'Доходность(все время)': [311.84], 'Доходность(% в год)': [15.52]}
# 146
#
# {'Название': ['Аквилон-Лизинг БО-03-001P'], 'Код': ['RU000A107M32'], 'Цена': [999.4], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [33], 'Дата купона': Timestamp('2024-04-23 00:00:00'), 'НКД': 30.0, 'Величина купона(-13%)': [38.37], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [153.48], 'Доходность(все время)': [306.96], 'Доходность(% в год)': [15.36]}
# 147
#
# ...
# 903
#
# {'Название': ['ОФЗ 29020'], 'Код': ['SU29020RMFS3'], 'Цена': [997.52], 'Рейтинг': ['Высокий'], 'Срок(месяца)': [41], 'Дата купона': Timestamp('2024-03-27 00:00:00'), 'НКД': 38.0, 'Величина купона(-13%)': [33.76], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [135.04], 'Доходность(все время)': [337.6], 'Доходность(% в год)': [13.54]}
# 904
#
# {'Название': ['ОФЗ 29024'], 'Код': ['SU29024RMFS5'], 'Цена': [976.0], 'Рейтинг': ['Высокий'], 'Срок(месяца)': [132], 'Дата купона': Timestamp('2024-05-01 00:00:00'), 'НКД': 23.0, 'Величина купона(-13%)': [32.45], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [129.8], 'Доходность(все время)': [1070.85], 'Доходность(% в год)': [13.3]}
# 905
#
# {'Название': ['ДОМ.РФ ИА БО-001Р-18'], 'Код': ['RU000A104UV0'], 'Цена': [774.806656], 'Рейтинг': ['Высокий'], 'Срок(месяца)': [98], 'Дата купона': Timestamp('2024-03-28 00:00:00'), 'НКД': 9.0, 'Величина купона(-13%)': [8.79], 'Номинал': [782.08], 'Выплат в год': [12], 'Доходность(год)': [105.48], 'Доходность(все время)': [70.32], 'Доходность(% в год)': [13.61]}
# 906
#
# {'Название': ['ДОМ.РФ ИА БО выпуск 9'], 'Код': ['RU000A103N43'], 'Цена': [498.84224], 'Рейтинг': ['Средний'], 'Срок(месяца)': [89], 'Дата купона': Timestamp('2024-05-28 00:00:00'), 'НКД': 3.0, 'Величина купона(-13%)': [9.83], 'Номинал': [599.57], 'Выплат в год': [4], 'Доходность(год)': [39.32], 'Доходность(все время)': [216.26], 'Доходность(% в год)': [7.88]}
# 907
#
# {'Название': ['ОФЗ 29018'], 'Код': ['SU29018RMFS7'], 'Цена': [991.55], 'Рейтинг': ['Высокий'], 'Срок(месяца)': [92], 'Дата купона': Timestamp('2024-06-05 00:00:00'), 'НКД': 8.0, 'Величина купона(-13%)': [33.49], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [133.96], 'Доходность(все время)': [770.27], 'Доходность(% в год)': [13.51]}
# 908
#
# Облигация с колл-опционом
# {'Название': ['Металлоинвест 001P-04'], 'Код': ['RU000A105W08'], 'Цена': [1013.0], 'Рейтинг': ['Высокий'], 'Срок(месяца)': [34]}
# 909
#
# {'Название': ['ДОМ.РФ ИА 018P'], 'Код': ['RU000A102D46'], 'Цена': [326.510014], 'Рейтинг': ['Средний'], 'Срок(месяца)': [323], 'Дата купона': Timestamp('2024-05-28 00:00:00'), 'НКД': 1.0, 'Величина купона(-13%)': [5.13], 'Номинал': [415.46], 'Выплат в год': [4], 'Доходность(год)': [20.52], 'Доходность(все время)': [410.4], 'Доходность(% в год)': [6.28]}
# 910
#
# {'Название': ['ОФЗ 29019'], 'Код': ['SU29019RMFS5'], 'Цена': [992.7], 'Рейтинг': ['Высокий'], 'Срок(месяца)': [63], 'Дата купона': Timestamp('2024-04-24 00:00:00'), 'НКД': 26.0, 'Величина купона(-13%)': [32.02], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [128.08], 'Доходность(все время)': [480.3], 'Доходность(% в год)': [12.9]}
# 911
#
# {'Название': ['Газпром Капитал БО-002P-09'], 'Код': ['RU000A107050'], 'Цена': [993.7], 'Рейтинг': ['Высокий'], 'Срок(месяца)': [48], 'Дата купона': Timestamp('2024-04-09 00:00:00'), 'НКД': 35.0, 'Величина купона(-13%)': [33.84], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [135.36], 'Доходность(все время)': [406.08], 'Доходность(% в год)': [13.62]}
# 912
#
# {'Название': ['ВЭБ.РФ ПБО-2 выпуск 31'], 'Код': ['RU000A1042W6'], 'Цена': [1003.0], 'Рейтинг': ['Высокий'], 'Срок(месяца)': [54], 'Дата купона': Timestamp('2024-04-24 00:00:00'), 'НКД': 29.0, 'Величина купона(-13%)': [34.8], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [139.2], 'Доходность(все время)': [452.4], 'Доходность(% в год)': [13.88]}
# 913
#
# {'Название': ['ОФЗ 29017'], 'Код': ['SU29017RMFS9'], 'Цена': [988.91], 'Рейтинг': ['Высокий'], 'Срок(месяца)': [101], 'Дата купона': Timestamp('2024-06-05 00:00:00'), 'НКД': 8.0, 'Величина купона(-13%)': [33.49], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [133.96], 'Доходность(все время)': [837.25], 'Доходность(% в год)': [13.55]}
# 914
#
# {'Название': ['Альфа-Банк 001Р выпуск 7'], 'Код': ['RU000A106VT7'], 'Цена': [1001.5], 'Рейтинг': ['Высокий'], 'Срок(месяца)': [5], 'Дата купона': Timestamp('2024-04-22 00:00:00'), 'НКД': 10.0, 'Величина купона(-13%)': [11.05], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [132.6], 'Доходность(все время)': [0.0], 'Доходность(% в год)': [13.24]}
# 915
#
# {'Название': ['Селигдар Золотые облигации'], 'Код': ['RU000A1062M5'], 'Цена': [6823.790103], 'Рейтинг': ['Высокий'], 'Срок(месяца)': [48], 'Дата купона': Timestamp('2024-04-05 00:00:00'), 'НКД': 77.0, 'Величина купона(-13%)': [76.04], 'Номинал': [6377.97], 'Выплат в год': [4], 'Доходность(год)': [304.16], 'Доходность(все время)': [912.48], 'Доходность(% в год)': [4.46]}
# 916
#
# Облигация с колл-опционом
# {'Название': ['КИВИ Финанс 001Р-02'], 'Код': ['RU000A107548'], 'Цена': [900.0], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [43]}
# 917
#
# Облигация с колл-опционом
# {'Название': ['TCS-perp1'], 'Код': ['RU000A107738'], 'Цена': [95113.4299416], 'Рейтинг': ['Высокий']}
# 918
#
# {'Название': ['ГазКап2P12'], 'Код': ['RU000A107T27'], 'Цена': [997.3], 'Рейтинг': ['Средний'], 'Срок(месяца)': [58], 'Дата купона': Timestamp('2024-05-20 00:00:00'), 'НКД': 16.0, 'Номинал': [1000.0], 'Величина купона(-13%)': [0], 'Выплат в год': [4], 'Доходность(год)': [0], 'Доходность(все время)': [0], 'Доходность(% в год)': [0.0]}
# 919
#
# {'Название': ['ОФЗ 29014'], 'Код': ['SU29014RMFS6'], 'Цена': [997.87], 'Рейтинг': ['Высокий'], 'Срок(месяца)': [24], 'Дата купона': Timestamp('2024-03-27 00:00:00'), 'НКД': 38.0, 'Величина купона(-13%)': [33.76], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [135.04], 'Доходность(все время)': [202.56], 'Доходность(% в год)': [13.53]}
# 920
#
# {'Название': ['ЕАБР 003Р-008'], 'Код': ['RU000A106JX4'], 'Цена': [1004.5], 'Рейтинг': ['Высокий'], 'Срок(месяца)': [51], 'Дата купона': Timestamp('2024-07-12 00:00:00'), 'НКД': 35.0, 'Величина купона(-13%)': [62.64], 'Номинал': [1000.0], 'Выплат в год': [2], 'Доходность(год)': [125.28], 'Доходность(все время)': [1566.0], 'Доходность(% в год)': [12.47]}
# 921
#
# {'Название': ['ДОМ.РФ ИА 09'], 'Код': ['RU000A102JB9'], 'Цена': [342.433586], 'Рейтинг': ['Средний'], 'Срок(месяца)': [320], 'Дата купона': Timestamp('2024-05-28 00:00:00'), 'НКД': 1.0, 'Величина купона(-13%)': [5.57], 'Номинал': [433.57], 'Выплат в год': [4], 'Доходность(год)': [22.28], 'Доходность(все время)': [445.6], 'Доходность(% в год)': [6.51]}
# 922
#
# {'Название': ['Газпром Капитал выпуск 7'], 'Код': ['RU000A106375'], 'Цена': [995.7], 'Рейтинг': ['Высокий'], 'Срок(месяца)': [48], 'Дата купона': Timestamp('2024-04-10 00:00:00'), 'НКД': 34.0, 'Величина купона(-13%)': [1.74], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [6.96], 'Доходность(все время)': [20.88], 'Доходность(% в год)': [0.7]}
# 923
#
# {'Название': ['Газпром Нефть 003P-09R'], 'Код': ['RU000A107HH9'], 'Цена': [1001.0], 'Рейтинг': ['Высокий'], 'Срок(месяца)': [44], 'Дата купона': Timestamp('2024-03-28 00:00:00'), 'НКД': 41.0, 'Номинал': [1000.0], 'Величина купона(-13%)': [0], 'Выплат в год': [4], 'Доходность(год)': [0], 'Доходность(все время)': [0], 'Доходность(% в год)': [0.0]}
# 924
#
# {'Название': ['Легенда 2Р-01'], 'Код': ['RU000A1067H4'], 'Цена': [1022.8], 'Рейтинг': ['Средний'], 'Срок(месяца)': [37], 'Дата купона': Timestamp('2024-05-09 00:00:00'), 'НКД': 25.0, 'Величина купона(-13%)': [43.33], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [173.32], 'Доходность(все время)': [389.97], 'Доходность(% в год)': [16.95]}
# 925
#
# {'Название': ['ОФЗ 29022'], 'Код': ['SU29022RMFS9'], 'Цена': [989.0], 'Рейтинг': ['Высокий'], 'Срок(месяца)': [111], 'Дата купона': Timestamp('2024-05-01 00:00:00'), 'НКД': 23.0, 'Величина купона(-13%)': [32.45], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [129.8], 'Доходность(все время)': [876.15], 'Доходность(% в год)': [13.12]}
# 926
#
# {'Название': ['SELGOLD002'], 'Код': ['RU000A106XD7'], 'Цена': [7029.798534], 'Рейтинг': ['Высокий'], 'Срок(месяца)': [69], 'Дата купона': Timestamp('2024-04-11 00:00:00'), 'НКД': 71.0, 'Величина купона(-13%)': [76.04], 'Номинал': [6377.97], 'Выплат в год': [4], 'Доходность(год)': [304.16], 'Доходность(все время)': [1292.68], 'Доходность(% в год)': [4.33]}
# 927
#
# {'Название': ['МТС выпуск 002P-01'], 'Код': ['RU000A1075E4'], 'Цена': [998.4], 'Рейтинг': ['Высокий'], 'Срок(месяца)': [43], 'Дата купона': Timestamp('2024-04-30 00:00:00'), 'НКД': 25.0, 'Номинал': [1000.0], 'Величина купона(-13%)': [0], 'Выплат в год': [4], 'Доходность(год)': [0], 'Доходность(все время)': [0], 'Доходность(% в год)': [0.0]}
# 928
#
# {'Название': ['Норильский никель БО-09'], 'Код': ['RU000A1069N8'], 'Цена': [1004.6], 'Рейтинг': ['Высокий'], 'Срок(месяца)': [49], 'Дата купона': Timestamp('2024-05-22 00:00:00'), 'НКД': 15.0, 'Величина купона(-13%)': [36.19], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [144.76], 'Доходность(все время)': [434.28], 'Доходность(% в год)': [14.41]}
# 929
#
# {'Название': ['ЕАБР выпуск 3Р-007'], 'Код': ['RU000A1064L3'], 'Цена': [1002.5], 'Рейтинг': ['Средний'], 'Срок(месяца)': [48], 'Дата купона': Timestamp('2024-04-25 00:00:00'), 'НКД': 71.0, 'Величина купона(-13%)': [48.72], 'Номинал': [1000.0], 'Выплат в год': [2], 'Доходность(год)': [97.44], 'Доходность(все время)': [1169.28], 'Доходность(% в год)': [9.72]}
# 930
#
# {'Название': ['ДОМ.РФ ИА 08'], 'Код': ['RU000A102GD1'], 'Цена': [319.6442], 'Рейтинг': ['Средний'], 'Срок(месяца)': [309], 'Дата купона': Timestamp('2024-03-28 00:00:00'), 'НКД': 5.0, 'Величина купона(-13%)': [5.05], 'Номинал': [389.81], 'Выплат в год': [4], 'Доходность(год)': [20.2], 'Доходность(все время)': [388.85], 'Доходность(% в год)': [6.32]}
# 931
#
# {'Название': ['РЖД 1P-27R'], 'Код': ['RU000A106VV3'], 'Цена': [1012.2], 'Рейтинг': ['Высокий'], 'Срок(месяца)': [41], 'Дата купона': Timestamp('2024-04-17 00:00:00'), 'НКД': 3.0, 'Величина купона(-13%)': [12.18], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [146.16], 'Доходность(все время)': [36.54], 'Доходность(% в год)': [14.44]}
# 932
#
# {'Название': ['Глобал Факторинг Нетворк Рус БО-04-001P'], 'Код': ['RU000A107CJ6'], 'Цена': [1019.1], 'Рейтинг': ['Высокий'], 'Срок(месяца)': [43], 'Дата купона': Timestamp('2024-04-09 00:00:00'), 'НКД': 9.0, 'Величина купона(-13%)': [15.66], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [187.92], 'Доходность(все время)': [46.98], 'Доходность(% в год)': [18.44]}
# 933
#
# {'Название': ['ИКС 5 ФИНАНС 003P-02'], 'Код': ['RU000A1075S4'], 'Цена': [1009.5], 'Рейтинг': ['Высокий'], 'Срок(месяца)': [30], 'Дата купона': Timestamp('2024-03-31 00:00:00'), 'НКД': 11.0, 'Величина купона(-13%)': [12.18], 'Номинал': [1000.0], 'Выплат в год': [12], 'Доходность(год)': [146.16], 'Доходность(все время)': [24.36], 'Доходность(% в год)': [14.48]}
# 934
#
# Облигация с колл-опционом
# {'Название': ['Сибнефтехимтрейд выпуск 2'], 'Код': ['RU000A104DZ7'], 'Цена': [1030.1], 'Рейтинг': ['Низкий'], 'Срок(месяца)': [32]}
# 935
#
# {'Название': ['Авто Финанс Банк БO-001P-11'], 'Код': ['RU000A107HR8'], 'Цена': [1011.5], 'Рейтинг': ['Высокий'], 'Срок(месяца)': [32], 'Дата купона': Timestamp('2024-03-28 00:00:00'), 'НКД': 44.0, 'Величина купона(-13%)': [40.11], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [160.44], 'Доходность(все время)': [320.88], 'Доходность(% в год)': [15.86]}
# 936
#
# {'Название': ['ПИК-Специализированный застройщик выпуск 4'], 'Код': ['RU000A0ZZ1M2'], 'Цена': [1053.0], 'Рейтинг': ['Высокий'], 'Срок(месяца)': [47], 'Дата купона': Timestamp('2024-03-29 00:00:00'), 'НКД': 65.0, 'Величина купона(-13%)': [58.55], 'Номинал': [1000.0], 'Выплат в год': [2], 'Доходность(год)': [117.1], 'Доходность(все время)': [1346.65], 'Доходность(% в год)': [11.12]}
# 937
#
# {'Название': ['Мосгорломбард'], 'Код': ['RU000A104XJ9'], 'Цена': [1120.0], 'Рейтинг': ['Средний'], 'Срок(месяца)': [33], 'Дата купона': Timestamp('2024-04-02 00:00:00'), 'НКД': 56.0, 'Величина купона(-13%)': [54.2], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [216.8], 'Доходность(все время)': [433.6], 'Доходность(% в год)': [19.36]}
# 938
#
# {'Название': ['ТМК 001Р выпуск 3'], 'Код': ['RU000A102TJ1'], 'Цена': [-1], 'Рейтинг': ['Средний'], 'Срок(месяца)': [11], 'Дата купона': Timestamp('2024-05-31 00:00:00'), 'НКД': 4.0, 'Величина купона(-13%)': [15.92], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [63.68], 'Доходность(все время)': [31.84], 'Доходность(% в год)': [-6368.0]}
# 939
#
# {'Название': ['Сегежа Групп 002P-07R'], 'Код': ['RU000A105AD7'], 'Цена': [-1], 'Рейтинг': ['Средний'], 'Срок(месяца)': [0], 'Дата купона': Timestamp('2024-04-10 00:00:00'), 'НКД': 22.0, 'Величина купона(-13%)': [1.74], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [6.96], 'Доходность(все время)': [0.0], 'Доходность(% в год)': [-696.0]}
# 940
#
# {'Название': ['Сегежа 002P выпуск 2'], 'Код': ['RU000A1043G7'], 'Цена': [-1], 'Рейтинг': ['Средний'], 'Срок(месяца)': [151], 'Дата купона': Timestamp('2024-05-21 00:00:00'), 'НКД': 33.0, 'Величина купона(-13%)': [42.02], 'Номинал': [1000.0], 'Выплат в год': [2], 'Доходность(год)': [84.04], 'Доходность(все время)': [3151.5], 'Доходность(% в год)': [-8404.0]}
# 941
#
# {'Название': ['Россети 001P выпуск 9'], 'Код': ['RU000A1065C9'], 'Цена': [-1], 'Рейтинг': ['Средний'], 'Срок(месяца)': [48], 'Дата купона': Timestamp('2024-04-23 00:00:00'), 'НКД': 17.0, 'Величина купона(-13%)': [22.62], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [90.48], 'Доходность(все время)': [271.44], 'Доходность(% в год)': [-9048.0]}
# 942
#
# {'Название': ['Россети 001P выпуск 10'], 'Код': ['RU000A1065A3'], 'Цена': [-1], 'Рейтинг': ['Средний'], 'Срок(месяца)': [72], 'Дата купона': Timestamp('2024-04-23 00:00:00'), 'НКД': 18.0, 'Величина купона(-13%)': [23.49], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [93.96], 'Доходность(все время)': [422.82], 'Доходность(% в год)': [-9396.0]}
# 943
#
# {'Название': ['РЖД'], 'Код': ['RU000A104SY8'], 'Цена': [-1], 'Рейтинг': ['Высокий'], 'Срок(месяца)': [37], 'Дата купона': Timestamp('2024-05-03 00:00:00'), 'НКД': 46.0, 'Величина купона(-13%)': [51.42], 'Номинал': [1000.0], 'Выплат в год': [2], 'Доходность(год)': [102.84], 'Доходность(все время)': [925.56], 'Доходность(% в год)': [-10284.0]}
# 944
#
# {'Название': ['ППК РЭО выпуск 1'], 'Код': ['RU000A105RW1'], 'Цена': [-1], 'Рейтинг': ['Средний'], 'Срок(месяца)': [104], 'Дата купона': Timestamp('2024-03-29 00:00:00'), 'НКД': 42.0, 'Величина купона(-13%)': [38.98], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [155.92], 'Доходность(все время)': [1013.48], 'Доходность(% в год)': [-15592.0]}
# 945
#
# {'Название': ['ЕвроХим выпуск 7'], 'Код': ['RU000A101L96'], 'Цена': [-1], 'Рейтинг': ['Средний'], 'Срок(месяца)': [12], 'Дата купона': Timestamp('2024-04-11 00:00:00'), 'НКД': 37.0, 'Величина купона(-13%)': [35.76], 'Номинал': [1000.0], 'Выплат в год': [2], 'Доходность(год)': [71.52], 'Доходность(все время)': [214.56], 'Доходность(% в год)': [-7152.0]}
# 946
#
# {'Название': ['Группа Черкизово'], 'Код': ['RU000A105M67'], 'Цена': [-1], 'Рейтинг': ['Средний'], 'Срок(месяца)': [44], 'Дата купона': Timestamp('2024-06-13 00:00:00'), 'НКД': 3.0, 'Величина купона(-13%)': [24.45], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [97.8], 'Доходность(все время)': [268.95], 'Доходность(% в год)': [-9780.0]}
# 947
#
# {'Название': ['Бизнес-Недвижимость выпуск 2'], 'Код': ['RU000A104BY4'], 'Цена': [-1], 'Рейтинг': ['Средний'], 'Срок(месяца)': [32], 'Дата купона': Timestamp('2024-06-21 00:00:00'), 'НКД': 0.0, 'Величина купона(-13%)': [23.4], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [93.6], 'Доходность(все время)': [187.2], 'Доходность(% в год)': [-9360.0]}
# 948
#
# {'Название': ['Автодор БО-5 выпуск 4'], 'Код': ['RU000A106XM8'], 'Цена': [-1], 'Рейтинг': ['Средний'], 'Срок(месяца)': [29], 'Дата купона': Timestamp('2024-04-26 00:00:00'), 'НКД': 22.0, 'Величина купона(-13%)': [30.28], 'Номинал': [1000.0], 'Выплат в год': [4], 'Доходность(год)': [121.12], 'Доходность(все время)': [211.96], 'Доходность(% в год)': [-12112.0]}
# 949
#
# Вышли из функции, поскольку Больше страниц нет

# %%
df = parser.obligations_data.reset_index().drop('index', axis = 1)

# %%
df[df['Название'].str.contains("Самолет")]
# Out:
#                  Название           Код   Цена  Рейтинг  Срок(месяца)  \
# 300   ГК Самолет выпуск 6  RU000A100QA0  981.9  Средний          64.0
# 362  ГК Самолет выпуск 10  RU000A103L03  974.9  Высокий           4.0
# 401  ГК Самолет выпуск 11  RU000A104JQ3  976.4  Высокий          46.0
# 440  ГК Самолет выпуск 13  RU000A107RZ0  996.0  Высокий          33.0
# 454  ГК Самолет выпуск 12  RU000A104YT6  979.9  Высокий          15.0
#
#     Дата купона   НКД  Величина купона(-13%)  Номинал  Выплат в год  \
# 300  2024-05-08  14.0                  24.36   1000.0           4.0
# 362  2024-05-22   8.0                  19.84   1000.0           4.0
# 401  2024-08-13  14.0                  55.07   1000.0           2.0
# 440         NaT   NaN                    NaN      NaN           NaN
# 454  2024-04-12  26.0                  28.71   1000.0           4.0
#
#      Доходность(год)  Доходность(все время)  Доходность(% в год)  \
# 300            97.44                 389.76                 9.92
# 362            79.36                  19.84                 8.14
# 401           110.14                1266.61                11.28
# 440              NaN                    NaN                  NaN
# 454           114.84                  86.13                11.72
#
#                                                 Ссылка
# 300  https://www.tinkoff.ru/invest/bonds/RU000A100QA0/
# 362  https://www.tinkoff.ru/invest/bonds/RU000A103L03/
# 401  https://www.tinkoff.ru/invest/bonds/RU000A104JQ3/
# 440  https://www.tinkoff.ru/invest/bonds/RU000A107RZ0/
# 454  https://www.tinkoff.ru/invest/bonds/RU000A104YT6/

# %%
df.to_csv(f'Obligations_data_parsed_{df["Код"].size}_{datetime.strftime(datetime.now(), "%d.%m.%Y")}.csv')

# %%
df
# Out:
#                          Название           Код       Цена  Рейтинг  \
# 0                Роснано выпуск 8  RU000A1008V9      857.2  Средний
# 1                Ferroni выпуск 1  RU000A103XP8      840.5   Низкий
# 2        Роснано БО-002P выпуск 4  RU000A101KK0      993.9   Низкий
# 3       МФК Быстроденьги выпуск 2  RU000A102ZT7      997.4   Низкий
# 4                       Alfa Bank  RU000A100GW5  8500000.0  Средний
# ..                            ...           ...        ...      ...
# 944              ППК РЭО выпуск 1  RU000A105RW1       -1.0  Средний
# 945              ЕвроХим выпуск 7  RU000A101L96       -1.0  Средний
# 946              Группа Черкизово  RU000A105M67       -1.0  Средний
# 947  Бизнес-Недвижимость выпуск 2  RU000A104BY4       -1.0  Средний
# 948         Автодор БО-5 выпуск 4  RU000A106XM8       -1.0  Средний
#
#      Срок(месяца) Дата купона   НКД  Величина купона(-13%)  Номинал  \
# 0            48.0  2024-04-01  64.0                  58.20   1000.0
# 1            18.0  2024-04-15   3.0                   9.22   1000.0
# 2             0.0  2024-03-26  16.0                  14.79   1000.0
# 3             0.0  2024-03-28   9.0                   9.05   1000.0
# 4             NaN         NaT   NaN                    NaN      NaN
# ..            ...         ...   ...                    ...      ...
# 944         104.0  2024-03-29  42.0                  38.98   1000.0
# 945          12.0  2024-04-11  37.0                  35.76   1000.0
# 946          44.0  2024-06-13   3.0                  24.45   1000.0
# 947          32.0  2024-06-21   0.0                  23.40   1000.0
# 948          29.0  2024-04-26  22.0                  30.28   1000.0
#
#      Выплат в год  Доходность(год)  Доходность(все время)  \
# 0             2.0           116.40                1396.80
# 1            12.0           110.64                   9.22
# 2             4.0            59.16                   0.00
# 3            12.0           108.60                   0.00
# 4             NaN              NaN                    NaN
# ..            ...              ...                    ...
# 944           4.0           155.92                1013.48
# 945           2.0            71.52                 214.56
# 946           4.0            97.80                 268.95
# 947           4.0            93.60                 187.20
# 948           4.0           121.12                 211.96
#
#      Доходность(% в год)                                             Ссылка
# 0                  13.58  https://www.tinkoff.ru/invest/bonds/RU000A1008V9/
# 1                  13.16  https://www.tinkoff.ru/invest/bonds/RU000A103XP8/
# 2                   5.95  https://www.tinkoff.ru/invest/bonds/RU000A101KK0/
# 3                  10.89  https://www.tinkoff.ru/invest/bonds/RU000A102ZT7/
# 4                    NaN  https://www.tinkoff.ru/invest/bonds/RU000A100GW5/
# ..                   ...                                                ...
# 944            -15592.00  https://www.tinkoff.ru/invest/bonds/RU000A105RW1/
# 945             -7152.00  https://www.tinkoff.ru/invest/bonds/RU000A101L96/
# 946             -9780.00  https://www.tinkoff.ru/invest/bonds/RU000A105M67/
# 947             -9360.00  https://www.tinkoff.ru/invest/bonds/RU000A104BY4/
# 948            -12112.00  https://www.tinkoff.ru/invest/bonds/RU000A106XM8/
#
# [949 rows x 14 columns]

# %%
dataprocessing.plot_papers(df)

# %% [markdown]
# ---

# %%
df = df.query('Цена <= 10000 & Цена > 0')
df = df[df['Доходность(% в год)'] >= 12]
df.dropna(inplace=True)

# %%
df
# Out:
#                                     Название           Код    Цена  Рейтинг  \
# 0                           Роснано выпуск 8  RU000A1008V9   857.2  Средний
# 1                           Ferroni выпуск 1  RU000A103XP8   840.5   Низкий
# 11                             Пионер-Лизинг  RU000A104V00  1000.1   Низкий
# 15                   АПРИ Флай Плэнинг БО-П5  RU000A103N19   921.4   Низкий
# 16                           МигКредит БО-03  RU000A106UK8   979.4   Низкий
# ..                                       ...           ...     ...      ...
# 931                               РЖД 1P-27R  RU000A106VV3  1012.2  Высокий
# 932  Глобал Факторинг Нетворк Рус БО-04-001P  RU000A107CJ6  1019.1  Высокий
# 933                     ИКС 5 ФИНАНС 003P-02  RU000A1075S4  1009.5  Высокий
# 935              Авто Финанс Банк БO-001P-11  RU000A107HR8  1011.5  Высокий
# 937                            Мосгорломбард  RU000A104XJ9  1120.0  Средний
#
#      Срок(месяца) Дата купона   НКД  Величина купона(-13%)  Номинал  \
# 0            48.0  2024-04-01  64.0                  58.20   1000.0
# 1            18.0  2024-04-15   3.0                   9.22   1000.0
# 11           96.0  2024-03-28  15.0                  14.79   1000.0
# 15           17.0  2024-06-04   7.0                  28.19   1000.0
# 16           28.0  2024-04-04   9.0                  11.92   1000.0
# ..            ...         ...   ...                    ...      ...
# 931          41.0  2024-04-17   3.0                  12.18   1000.0
# 932          43.0  2024-04-09   9.0                  15.66   1000.0
# 933          30.0  2024-03-31  11.0                  12.18   1000.0
# 935          32.0  2024-03-28  44.0                  40.11   1000.0
# 937          33.0  2024-04-02  56.0                  54.20   1000.0
#
#      Выплат в год  Доходность(год)  Доходность(все время)  \
# 0             2.0           116.40                1396.80
# 1            12.0           110.64                   9.22
# 11           12.0           177.48                 118.32
# 15            4.0           112.76                 112.76
# 16           12.0           143.04                  23.84
# ..            ...              ...                    ...
# 931          12.0           146.16                  36.54
# 932          12.0           187.92                  46.98
# 933          12.0           146.16                  24.36
# 935           4.0           160.44                 320.88
# 937           4.0           216.80                 433.60
#
#      Доходность(% в год)                                             Ссылка
# 0                  13.58  https://www.tinkoff.ru/invest/bonds/RU000A1008V9/
# 1                  13.16  https://www.tinkoff.ru/invest/bonds/RU000A103XP8/
# 11                 17.75  https://www.tinkoff.ru/invest/bonds/RU000A104V00/
# 15                 12.24  https://www.tinkoff.ru/invest/bonds/RU000A103N19/
# 16                 14.60  https://www.tinkoff.ru/invest/bonds/RU000A106UK8/
# ..                   ...                                                ...
# 931                14.44  https://www.tinkoff.ru/invest/bonds/RU000A106VV3/
# 932                18.44  https://www.tinkoff.ru/invest/bonds/RU000A107CJ6/
# 933                14.48  https://www.tinkoff.ru/invest/bonds/RU000A1075S4/
# 935                15.86  https://www.tinkoff.ru/invest/bonds/RU000A107HR8/
# 937                19.36  https://www.tinkoff.ru/invest/bonds/RU000A104XJ9/
#
# [250 rows x 14 columns]

# %%
df['Дата купона'] = df['Дата купона'].apply(lambda x: pd.to_datetime(x))

# %%
df.sort_values('Доходность(% в год)', ascending=False)
# Out:
#                           Название           Код     Цена  Рейтинг  \
# 574   АПРИ Флай Плэнинг БО-002Р-04  RU000A107FZ5  1067.00   Низкий
# 937                  Мосгорломбард  RU000A104XJ9  1120.00  Средний
# 112           Мани Капитал 001P-02  RU000A1079G1   986.50   Низкий
# 81          МФК Быстроденьги 2P-03  RU000A1070G0   947.40  Средний
# 63            Мани Капитал 001P-01  RU000A1074F4   948.00  Средний
# ..                             ...           ...      ...      ...
# 147            Элит Строй выпуск 1  RU000A103M85   987.00  Средний
# 423               Новые технологии  RU000A105DL4   971.80  Высокий
# 550                     ГТЛК БО-04  RU000A0JVA10   994.40  Высокий
# 688  Оренбургская область выпуск 3  RU000A0JVM81   401.64  Высокий
# 375           ЕвроТранс БО-001P-03  RU000A1061K1   964.90  Средний
#
#      Срок(месяца) Дата купона   НКД  Величина купона(-13%)  Номинал  \
# 574          44.0  2024-06-21   2.0                  52.03   1000.0
# 937          33.0  2024-04-02  56.0                  54.20   1000.0
# 112          31.0  2024-03-27  16.0                  15.66   1000.0
# 81           35.0  2024-04-08   9.0                  14.96   1000.0
# 63           30.0  2024-04-21   1.0                  14.96   1000.0
# ..            ...         ...   ...                    ...      ...
# 147           4.0  2024-04-17   2.0                  10.00   1000.0
# 423          43.0  2024-05-07  51.0                  58.55   1000.0
# 550          11.0  2024-06-06   6.0                  29.93   1000.0
# 688          15.0  2024-04-04  12.0                  12.09    400.0
# 375          35.0  2024-03-29   9.0                   9.66   1000.0
#
#      Выплат в год  Доходность(год)  Доходность(все время)  \
# 574           4.0           208.12                 572.33
# 937           4.0           216.80                 433.60
# 112          12.0           187.92                  31.32
# 81           12.0           179.52                  29.92
# 63           12.0           179.52                  29.92
# ..            ...              ...                    ...
# 147          12.0           120.00                   0.00
# 423           2.0           117.10                1229.55
# 550           4.0           119.72                  59.86
# 688           4.0            48.36                  36.27
# 375          12.0           115.92                  19.32
#
#      Доходность(% в год)                                             Ссылка
# 574                19.51  https://www.tinkoff.ru/invest/bonds/RU000A107FZ5/
# 937                19.36  https://www.tinkoff.ru/invest/bonds/RU000A104XJ9/
# 112                19.05  https://www.tinkoff.ru/invest/bonds/RU000A1079G1/
# 81                 18.95  https://www.tinkoff.ru/invest/bonds/RU000A1070G0/
# 63                 18.94  https://www.tinkoff.ru/invest/bonds/RU000A1074F4/
# ..                   ...                                                ...
# 147                12.16  https://www.tinkoff.ru/invest/bonds/RU000A103M85/
# 423                12.05  https://www.tinkoff.ru/invest/bonds/RU000A105DL4/
# 550                12.04  https://www.tinkoff.ru/invest/bonds/RU000A0JVA10/
# 688                12.04  https://www.tinkoff.ru/invest/bonds/RU000A0JVM81/
# 375                12.01  https://www.tinkoff.ru/invest/bonds/RU000A1061K1/
#
# [250 rows x 14 columns]

# %%
# df[df['Код'] == 'RU000A106888']
df[df['Название'].str.contains("Самолет")]
# Out:
# Empty DataFrame
# Columns: [Название, Код, Цена, Рейтинг, Срок(месяца), Дата купона, НКД, Величина купона(-13%), Номинал, Выплат в год, Доходность(год), Доходность(все время), Доходность(% в год), Ссылка]
# Index: []

# %%
df[df['НКД'] == 0].sort_values('Доходность(% в год)', ascending=False)
# Out:
#                                           Название           Код         Цена  \
# 38                          МФК ВЭББАНКИР выпуск 4  RU000A106Y88   929.600000
# 473                       Нафтатранс Плюс выпуск 5  RU000A106Y21  1039.500000
# 896                      ВсеИнструменты.ру 001P-01  RU000A107GJ7  1014.900000
# 493                          Нафтатранс Плюс БО-04  RU000A105CF8  1062.000000
# 786                         РСХБ выпуск БО-02-002Р  RU000A1068R1  1005.000000
# 149                          АйДи Коллект выпуск 4  RU000A106XT3   982.000000
# 57                             МФК ВЭББАНКИР 1P-02  RU000A105575   901.200000
# 520                              Sunlight выпуск 1  RU000A1074Q1  1007.900000
# 782                       МСБ-Лизинг 002P выпуск 2  RU000A100DC4    41.853456
# 699                      Магаданская область 34002  RU000A105NT6   940.000000
# 373        Первое коллекторское бюро 001Р выпуск 2  RU000A103RJ3   578.220000
# 216                            МФК Займер выпуск 2  RU000A103CW8   331.598400
# 526                                      Славнефть  RU000A104WF9   948.000000
# 770                    Удмуртская республика 35002  RU000A0JWT91   975.200000
# 132                       Петроинжиниринг выпуск 1  RU000A103RL9   962.400000
# 307                        ГК Пионер-001Р выпуск 5  RU000A102KG6   490.708500
# 696                    Самарская область выпуск 12  RU000A0JWM56   247.825000
# 767                      Республика Коми выпуск 14  RU000A0JXUD9   495.150000
# 753                                      ОФЗ 26237  SU26237RMFS6   780.440000
# 752                                      ОФЗ 26235  SU26235RMFS0   687.730000
# 650                             Казахстан выпуск 7  RU000A101RV2   795.800000
# 799                  Ярославская область выпуск 16  RU000A0ZZEM5   691.950000
# 792              Тинькофф Ипотечный Агент выпуск 1  RU000A103D37   187.328204
# 795                      Томская область выпуск 62  RU000A0ZYMJ7   243.975000
# 508                                      Краснодар  RU000A102KT9   554.040000
# 800                           СУЭК-Финанс выпуск 3  RU000A100VG7   976.000000
# 346  Верхнебаканский цементный завод 001P выпуск 1  RU000A0ZYLK7   899.900000
# 479                          РУСАЛ Братск выпуск 1  RU000A0JWDN6   744.000000
# 947                   Бизнес-Недвижимость выпуск 2  RU000A104BY4    -1.000000
#
#      Рейтинг  Срок(месяца) Дата купона  НКД  Величина купона(-13%)  Номинал  \
# 38    Низкий          35.0  2024-03-24  0.0                  14.27  1000.00
# 473  Средний          29.0  2024-03-24  0.0                  13.57  1000.00
# 896  Высокий          32.0  2024-03-24  0.0                  13.22  1000.00
# 493  Средний          18.0  2024-03-24  0.0                  13.57  1000.00
# 786  Высокий          25.0  2024-03-24  0.0                  12.79  1000.00
# 149   Низкий          29.0  2024-03-23  0.0                  11.74  1000.00
# 57    Низкий          22.0  2024-03-23  0.0                  10.00  1000.00
# 520  Высокий          12.0  2024-03-23  0.0                  10.88  1000.00
# 782  Средний           1.0  2024-03-31  0.0                   0.35    41.82
# 699  Средний          44.0  2024-06-21  0.0                  22.97  1000.00
# 373  Средний          17.0  2024-06-21  0.0                  13.92   600.00
# 216   Низкий           2.0  2024-03-24  0.0                   2.61   333.60
# 526  Высокий          98.0  2024-06-21  0.0                  22.01  1000.00
# 770  Высокий          29.0  2024-03-23  0.0                  22.62  1000.00
# 132  Средний          29.0  2024-06-21  0.0                  21.14  1000.00
# 307  Средний           8.0  2024-06-18  0.0                  10.61   505.00
# 696  Высокий           2.0  2024-06-21  0.0                   5.22   250.00
# 767  Высокий           3.0  2024-06-25  0.0                   9.74   500.00
# 753  Высокий          59.0  2024-09-18  0.0                  29.06  1000.00
# 752  Высокий          83.0  2024-09-18  0.0                  25.58  1000.00
# 650  Средний          41.0  2024-09-18  0.0                  28.36  1000.00
# 799  Высокий          17.0  2024-03-24  0.0                  12.01   700.00
# 792  Высокий         119.0  2024-03-23  0.0                   3.22   188.44
# 795  Средний           8.0  2024-06-20  0.0                   4.00   250.00
# 508  Высокий          20.0  2024-06-20  0.0                   8.70   600.00
# 800  Средний          65.0  2024-09-19  0.0                   8.61  1000.00
# 346  Средний          44.0  2024-06-14  0.0                   1.57  1000.00
# 479  Высокий          24.0  2024-04-09  0.0                   0.00  1000.00
# 947  Средний          32.0  2024-06-21  0.0                  23.40  1000.00
#
#      Выплат в год  Доходность(год)  Доходность(все время)  \
# 38           12.0           171.24                  28.54
# 473          12.0           162.84                  27.14
# 896          12.0           158.64                  26.44
# 493          12.0           162.84                  13.57
# 786          12.0           153.48                  25.58
# 149          12.0           140.88                  23.48
# 57           12.0           120.00                  10.00
# 520          12.0           130.56                  10.88
# 782          12.0             4.20                   0.00
# 699           4.0            91.88                 252.67
# 373           4.0            55.68                  55.68
# 216          12.0            31.32                   0.00
# 526           4.0            88.04                 528.24
# 770           4.0            90.48                 158.34
# 132           4.0            84.56                 147.98
# 307           4.0            42.44                  21.22
# 696           4.0            20.88                   0.00
# 767           4.0            38.96                   0.00
# 753           2.0            58.12                 842.74
# 752           2.0            51.16                1048.78
# 650           2.0            56.72                 567.20
# 799           4.0            48.04                  48.04
# 792           4.0            12.88                  93.38
# 795           4.0            16.00                   8.00
# 508           4.0            34.80                  43.50
# 800           2.0            17.22                 275.52
# 346           4.0             6.28                  17.27
# 479           2.0             0.00                   0.00
# 947           4.0            93.60                 187.20
#
#      Доходность(% в год)                                             Ссылка
# 38                 18.42  https://www.tinkoff.ru/invest/bonds/RU000A106Y88/
# 473                15.67  https://www.tinkoff.ru/invest/bonds/RU000A106Y21/
# 896                15.63  https://www.tinkoff.ru/invest/bonds/RU000A107GJ7/
# 493                15.33  https://www.tinkoff.ru/invest/bonds/RU000A105CF8/
# 786                15.27  https://www.tinkoff.ru/invest/bonds/RU000A1068R1/
# 149                14.35  https://www.tinkoff.ru/invest/bonds/RU000A106XT3/
# 57                 13.32  https://www.tinkoff.ru/invest/bonds/RU000A105575/
# 520                12.95  https://www.tinkoff.ru/invest/bonds/RU000A1074Q1/
# 782                10.04  https://www.tinkoff.ru/invest/bonds/RU000A100DC4/
# 699                 9.77  https://www.tinkoff.ru/invest/bonds/RU000A105NT6/
# 373                 9.63  https://www.tinkoff.ru/invest/bonds/RU000A103RJ3/
# 216                 9.45  https://www.tinkoff.ru/invest/bonds/RU000A103CW8/
# 526                 9.29  https://www.tinkoff.ru/invest/bonds/RU000A104WF9/
# 770                 9.28  https://www.tinkoff.ru/invest/bonds/RU000A0JWT91/
# 132                 8.79  https://www.tinkoff.ru/invest/bonds/RU000A103RL9/
# 307                 8.65  https://www.tinkoff.ru/invest/bonds/RU000A102KG6/
# 696                 8.43  https://www.tinkoff.ru/invest/bonds/RU000A0JWM56/
# 767                 7.87  https://www.tinkoff.ru/invest/bonds/RU000A0JXUD9/
# 753                 7.45  https://www.tinkoff.ru/invest/bonds/SU26237RMFS6/
# 752                 7.44  https://www.tinkoff.ru/invest/bonds/SU26235RMFS0/
# 650                 7.13  https://www.tinkoff.ru/invest/bonds/RU000A101RV2/
# 799                 6.94  https://www.tinkoff.ru/invest/bonds/RU000A0ZZEM5/
# 792                 6.88  https://www.tinkoff.ru/invest/bonds/RU000A103D37/
# 795                 6.56  https://www.tinkoff.ru/invest/bonds/RU000A0ZYMJ7/
# 508                 6.28  https://www.tinkoff.ru/invest/bonds/RU000A102KT9/
# 800                 1.76  https://www.tinkoff.ru/invest/bonds/RU000A100VG7/
# 346                 0.70  https://www.tinkoff.ru/invest/bonds/RU000A0ZYLK7/
# 479                 0.00  https://www.tinkoff.ru/invest/bonds/RU000A0JWDN6/
# 947             -9360.00  https://www.tinkoff.ru/invest/bonds/RU000A104BY4/

# %%
dataprocessing.plot_papers(df)
