# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv('Obligations_data_parsed_833_09.10.2023.csv', index_col=0).fillna(-1).infer_objects()

# %%
df.sort_values(["Доходность(% в год)", 'Доходность(все время)' ], ascending=False)
# Out:
#                        Название           Код  Срок(месяца)    Цена  Рейтинг  \
# 763           АПРИ Флай Плэнинг  RU000A105DS9          36.0  1013.5  Средний
# 50           Завод КЭС выпуск 4  RU000A106QS9          57.0   927.1   Низкий
# 16   АПРИ Флай Плэнинг выпуск 3  RU000A106WZ2          47.0  1022.2  Средний
# 47       МФК ВЭББАНКИР выпуск 4  RU000A106Y88          41.0  1002.5  Средний
# 818               Мосгорломбард  RU000A104XJ9          38.0  1129.1   Низкий
# ..                          ...           ...           ...     ...      ...
# 826      Россети 001P выпуск 10  RU000A1065A3          78.0    -1.0  Средний
# 830            Группа Черкизово  RU000A105M67          49.0    -1.0  Средний
# 827                         РЖД  RU000A104SY8          42.0    -1.0  Высокий
# 828            ППК РЭО выпуск 1  RU000A105RW1         110.0    -1.0  Средний
# 832       Автодор БО-5 выпуск 4  RU000A106XM8          35.0    -1.0  Средний
#
# ...

# %%
a = df.query("(Рейтинг == 'Средний' | Рейтинг == 'Высокий') & Цена > 0")
a = a[a["Срок(месяца)"] >= 12]

# %%
b = a[a['Доходность(% в год)'] > 15]
b.sort_values('Доходность(% в год)', ascending=False)
# Out:
#                        Название           Код  Срок(месяца)    Цена  Рейтинг  \
# 763           АПРИ Флай Плэнинг  RU000A105DS9          36.0  1013.5  Средний
# 16   АПРИ Флай Плэнинг выпуск 3  RU000A106WZ2          47.0  1022.2  Средний
# 47       МФК ВЭББАНКИР выпуск 4  RU000A106Y88          41.0  1002.5  Средний
# 17             Эфферон выпуск 1  RU000A105H98          49.0   921.2  Средний
# 44     Нафтатранс Плюс выпуск 5  RU000A106Y21          35.0  1027.1  Средний
# 286          Завод КЭС выпуск 3  RU000A105AW7          36.0  1115.9  Средний
# 33     Альфа Дон Транс выпуск 1  RU000A106Y70          23.0  1009.0  Средний
# 19              Селлер выпуск 2  RU000A106X30          34.0  1001.2  Средний
#
#      Величина купона(-13%)  Номинал  Выплат в год  Доходность(год)  \
# 763                  52.03   1000.0           4.0           208.12
# 16                   45.50   1000.0           4.0           182.00
# 47                   14.27   1000.0          12.0           171.24
# ...
