# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv('Obligations_data_parsed.csv')

# %%
df.sort_values(["Доходность(все время)", 'Доходность(% в год)' ], ascending=False)
# Out:
#      Unnamed: 0                                  Название           Код  \
# 414         414                      Банк ДОМ.РФ СУБ-Т2-1  RU000A105XG2
# 785         785                          ВТБ СУБ выпуск 5  RU000A1034P7
# 147         147                       Сбербанк 002СУБ-03R  RU000A103Q24
# 80           80                       Сбербанк 002СУБ-02R  RU000A102HC1
# 8             8                                 Alfa Bank  RU000A100GW5
# ..          ...                                       ...           ...
# 783         783  СОПФ Инфраструктурные облигации выпуск 6  RU000A106P97
# 784         784                      РЕСО-Лизинг выпуск 6  RU000A1049Y7
# 808         808                   Норильский никель БО-09  RU000A1069N8
# 809         809                        ЕАБР выпуск 3Р-007  RU000A1064L3
# 478         478                     Сбербанк выпуск SbD1R  RU000A103KG4
#
#      Срок(месяца)        Цена  Рейтинг  Величина купона(-13%)     Номинал  \
# ...

# %%
df[df['Рейтинг'] == 'Средний']
# Out:
#      Unnamed: 0                   Название           Код  Срок(месяца)  \
# 2             2           Роснано выпуск 8  RU000A1008V9            53
# 8             8                  Alfa Bank  RU000A100GW5            11
# 10           10  Газпром Капитал БЗО26-1-Е  RU000A105QX1            27
# 12           12              Киви выпуск 1  RU000A1028C7             8
# 16           16  Газпром Капитал БЗО26-1-Д  RU000A105QW3            27
# ..          ...                        ...           ...           ...
# 797         797      ДОМ.РФ ИА БО выпуск 9  RU000A103N43            94
# 799         799             ДОМ.РФ ИА 018P  RU000A102D46           328
# 805         805               ДОМ.РФ ИА 09  RU000A102JB9           325
# 809         809         ЕАБР выпуск 3Р-007  RU000A1064L3            54
# 810         810               ДОМ.РФ ИА 08  RU000A102GD1           314
#
#              Цена  Рейтинг  Величина купона(-13%)      Номинал  Выплат в год  \
# ...
